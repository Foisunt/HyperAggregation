# %%
from pathlib import Path
import yaml
import pandas as pd
import seaborn as sns
from tqdm import tqdm
import matplotlib.pyplot as plt
from utils import collect_res_dat
import copy

# %%
def collect_res_dat(p = Path("../results/test/")):
    outer_dfls = []
    for d in tqdm(list(p.glob("setting*"))):
        try:
            settings = yaml.safe_load((d/"settings.yml").open())
        except FileNotFoundError:
            print("FNF")
            continue
        del settings["statrep"]
        del settings["save_models"]
        del settings["epochs"]
        del settings["record_train"]
        
        #del settings["early_stopping"]
        dfls = []
        l = list(d.glob("stats_*.pkl"))
        if len(l) == 0:
            continue
        for sp in l:
            df = pd.read_pickle(str(sp))
            df["statrep"] = int(sp.parts[-1][6:-4])
            dfls.append(df)
        df = pd.concat(dfls)
        for k in settings:
            if type(settings[k])==dict or type(settings[k])==list:
                df[k]=str(settings[k])
            else:
                df[k]=settings[k]
                    # try:
            #     df[k]=str(settings[k])
            # except ValueError:
            #     df[k]=str(settings[k])
        outer_dfls.append(df)
    return pd.concat(outer_dfls, ignore_index=True)

def print2do():
    p = Path("../Experiments")
    ls = []
    for p in list(p.glob("*")):
        if str(p)[-3:] == "yml":
            settings = yaml.safe_load(p.open())
            if not settings.get("alldone", False):
                ls.append(str(p))
    ls.sort()
    print("\n".join(ls))

# %%
print2do()

# %% [markdown]
# ## Abl

# %%
# #trying to fix edas complaining about fonts
# plt.rc('text', usetex=True)
# plt.rc('font', family='serif')

# %%
# Cora 

orig = 78.85072112083435

df = pd.read_pickle(str(Path("../results_comb/hyp_abl_Cora_undir.pkl")))
print("undir", df.ds_undir.unique(), " & $", df.mean(numeric_only=True).test_acc*100-orig ,"$" )

df = pd.read_pickle(str(Path("../results_comb/hyp_abl_Cora_self.pkl")))
print("self", df.ds_self.unique(), " & $", df.mean(numeric_only=True).test_acc*100-orig ,"$" )

df = pd.read_pickle(str(Path("../results_comb/hyp_abl_Cora_trmid.pkl")))
print("trmid", df.tr_mid.unique(), " & $", df.mean(numeric_only=True).test_acc*100-orig ,"$" )

df = pd.read_pickle(str(Path("../results_comb/hyp_abl_Cora_trin.pkl")))
print("trin", df.tr_agg_in.unique(), " & $", df.mean(numeric_only=True).test_acc*100-orig ,"$" )

df = pd.read_pickle(str(Path("../results_comb/hyp_abl_Cora_res.pkl")))
print("lin", df.model_type.unique(), " & $", df.mean(numeric_only=True).test_acc*100-orig ,"$" )

df = pd.read_pickle(str(Path("../results_comb/hyp_abl_Cora_skip.pkl")))
print("skip", df.skip_mix.unique(), " & $", df.mean(numeric_only=True).test_acc*100-orig ,"$" )

df = pd.read_pickle(str(Path("../results_comb/hyp_abl_Cora_agg.pkl")))
print("mean", df.aggr_mean.unique(), " & $", df.mean(numeric_only=True).test_acc*100-orig ,"$" )

df = pd.read_pickle(str(Path("../results_comb/hyp_abl_Cora_norm.pkl")))
print("norm", df.norm_in.unique(), " & $", df.mean(numeric_only=True).test_acc*100-orig ,"$" )

# %%
pl = []

pl.append(Path("../results_comb/hyp_abl_Cora_hds.pkl"))
pl.append(Path("../results_comb/hyp_abl_Cora_hdb.pkl"))
pl.append(Path("../results_comb/hyp_abl_Cora_hdb2.pkl"))

df = pd.concat([pd.read_pickle(str(p)) for p in pl], ignore_index=True)

df["hid_dim"] = df.model.str.split("_", expand=True)[2].astype(int)

dfr = df.rename({"test_acc":"test accuracy", "mix_dim":"mixing dimension m", "drop_mix":"mixing dropout", "hid_dim": "hidden dimension h", "drop_model":"model dropout"}, axis=1)

sns.relplot(data=dfr, x="hidden dimension h", y="test accuracy", hue="model dropout", kind="line", errorbar=None, facet_kws={'sharey': False, 'sharex': True})
plt.xscale("log")
plt.ylim(.72,.8)

plt.savefig("../figs/abl_hc_hiddim_cora.png")

# %%
pl = []

pl.append(Path("../results_comb/hyp_abl_Cora_md.pkl"))
pl.append(Path("../results_comb/hyp_abl_Cora_md2.pkl"))
pl.append(Path("../results_comb/hyp_abl_Cora_md3.pkl"))
pl.append(Path("../results_comb/hyp_abl_Cora_md4.pkl"))

df = pd.concat([pd.read_pickle(str(p)) for p in pl], ignore_index=True)

df["mix_dim"] = df.model.str.split("_", expand=True)[3].astype(int)
df["hidden"] = df.model.str.split("_", expand=True)[2].astype(int)

dfr = df.rename({"test_acc":"test accuracy", "mix_dim":"mixing dimension m", "drop_mix":"mixing dropout", "hid_dim": "hidden dimension h", "drop_model":"model dropout"}, axis=1)

sns.relplot(data=dfr, x="mixing dimension m", y="test accuracy", hue="mixing dropout", kind="line", errorbar=None, facet_kws={'sharey': False, 'sharex': True})
plt.xscale("log")

plt.savefig("../figs/abl_hc_mixdim_cora.png")
plt.ylim(.72, .8)

# %%
# RE

orig = 92.27497100830078

df = pd.read_pickle(str(Path("../results_comb/hyp_abl_Re_undir.pkl")))
print("undir", df.ds_undir.unique(), " & $", df.mean(numeric_only=True).test_acc*100-orig ,"$" )

df = pd.read_pickle(str(Path("../results_comb/hyp_abl_Re_self.pkl")))
print("self", df.ds_self.unique(), " & $", df.mean(numeric_only=True).test_acc*100-orig ,"$" )

df = pd.read_pickle(str(Path("../results_comb/hyp_abl_Re_trmid.pkl")))
print("trmid", df.tr_mid.unique(), " & $", df.mean(numeric_only=True).test_acc*100-orig ,"$" )

df = pd.read_pickle(str(Path("../results_comb/hyp_abl_Re_trin.pkl")))
print("trin", df.tr_agg_in.unique(), " & $", df.mean(numeric_only=True).test_acc*100-orig ,"$" )

df = pd.read_pickle(str(Path("../results_comb/hyp_abl_Re_lin.pkl")))
print("lin", df.model_type.unique(), " & $", df.mean(numeric_only=True).test_acc*100-orig ,"$" )

df = pd.read_pickle(str(Path("../results_comb/hyp_abl_Re_skip.pkl")))
print("skip", df.skip_mix.unique(), " & $", df.mean(numeric_only=True).test_acc*100-orig ,"$" )

df = pd.read_pickle(str(Path("../results_comb/hyp_abl_Re_agg.pkl")))
print("mean", df.aggr_mean.unique(), " & $", df.mean(numeric_only=True).test_acc*100-orig ,"$" )

df = pd.read_pickle(str(Path("../results_comb/hyp_abl_Re_norm.pkl")))
print("norm", df.norm_in.unique(), " & $", df.mean(numeric_only=True).test_acc*100-orig ,"$" )

# %%
pl = []

pl.append(Path("../results_comb/hyp_abl_Re_hds.pkl"))
pl.append(Path("../results_comb/hyp_abl_Re_hdb.pkl"))

df = pd.concat([pd.read_pickle(str(p)) for p in pl], ignore_index=True)

df["hid_dim"] = df.model.str.split("_", expand=True)[2].astype(int)

dfr = df.rename({"test_acc":"test accuracy", "mix_dim":"mixing dimension m", "drop_mix":"mixing dropout", "hid_dim": "hidden dimension h", "drop_model":"model dropout"}, axis=1)

sns.relplot(data=dfr, x="hidden dimension h", y="test accuracy", hue="model dropout", kind="line", errorbar=None, facet_kws={'sharey': False, 'sharex': True})
plt.xscale("log")
#plt.ylim(.7,.83)

plt.savefig("../figs/abl_hc_hiddim_re.png")

# %%
pl = []

pl.append(Path("../results_comb/hyp_abl_Re_md1.pkl"))
pl.append(Path("../results_comb/hyp_abl_Re_md2.pkl"))
pl.append(Path("../results_comb/hyp_abl_Re_md3.pkl"))

df = pd.concat([pd.read_pickle(str(p)) for p in pl], ignore_index=True)

df["mix_dim"] = df.model.str.split("_", expand=True)[3].astype(int)
df["hidden"] = df.model.str.split("_", expand=True)[2].astype(int)

dfr = df.rename({"test_acc":"test accuracy", "mix_dim":"mixing dimension m", "drop_mix":"mixing dropout", "hid_dim": "hidden dimension h", "drop_model":"model dropout"}, axis=1)

sns.relplot(data=dfr, x="mixing dimension m", y="test accuracy", hue="mixing dropout", kind="line", errorbar=None, facet_kws={'sharey': False, 'sharex': True})
plt.xscale("log")

plt.savefig("../figs/abl_hc_mixdim_re.png")

# %% [markdown]
# ## Plot Grid Search Results

# %%
pl = []

pl.append(Path("../results_comb/search_GHC_RomanEmpire.pkl"))

df = pd.concat([pd.read_pickle(str(p)) for p in pl], ignore_index=True)


sns.relplot(data=df, x="weight_decay", y="val_acc", hue="drop_model", style="drop_input", col="drop_mix", kind="line", errorbar=None, facet_kws={'sharey': "row", 'sharex': True})
#plt.xscale("log")
plt.xscale('symlog', linthresh=0.00001)
plt.xlim(0,0.1)
#plt.ylim(.75,.95)

# %%
pl = []

pl.append(Path("../results_comb/sage_p_Act1.pkl"))
pl.append(Path("../results_comb/sage_p_Ch1.pkl"))
pl.append(Path("../results_comb/sage_p_Cite1.pkl"))
pl.append(Path("../results_comb/sage_p_Com1.pkl"))
pl.append(Path("../results_comb/sage_p_Cora1.pkl"))
pl.append(Path("../results_comb/sage_p_Ms1.pkl"))
pl.append(Path("../results_comb/sage_p_PM1.pkl"))
pl.append(Path("../results_comb/sage_p_Pho1.pkl"))
pl.append(Path("../results_comb/sage_p_Re1.pkl"))
pl.append(Path("../results_comb/sage_p_Sq1.pkl"))
pl.append(Path("../results_comb/sage_p_Arx10.pkl"))
pl.append(Path("../results_comb/sage_p_Arx11.pkl"))

df = pd.concat([pd.read_pickle(str(p)) for p in pl], ignore_index=True)

#df[df.batch_size.eq("2x50")].batch_size = "1x100"

#df["trim"] = df['tr_agg_in'].astype(str) +"-"+ df["tr_mid"].astype(str)

sns.relplot(data=df, x="weight_decay", y="val_acc", hue="drop_adj", style="drop_model", col="dataset", col_wrap=4, kind="line", errorbar=None, facet_kws={'sharey': False, 'sharex': True})
#plt.xscale("log")
plt.xscale('symlog', linthresh=0.00001)
plt.xlim(0,0.1)
#plt.ylim(.65,.73)

# %%
pl = []

pl.append(Path("../results_comb/sage_p_Act0b.pkl"))
#pl.append(Path("../results_comb/sage_p_Act0b2.pkl"))
pl.append(Path("../results_comb/sage_p_Ch0b.pkl"))
pl.append(Path("../results_comb/sage_p_Cite0b.pkl"))
pl.append(Path("../results_comb/sage_p_Com0b.pkl"))
pl.append(Path("../results_comb/sage_p_Cora0b.pkl"))
pl.append(Path("../results_comb/sage_p_Ms0b.pkl"))
pl.append(Path("../results_comb/sage_p_PM0b.pkl"))
pl.append(Path("../results_comb/sage_p_Pho0b.pkl"))
pl.append(Path("../results_comb/sage_p_Re0b.pkl"))
pl.append(Path("../results_comb/sage_p_Sq0b.pkl"))
pl.append(Path("../results_comb/sage_p_Arx0b.pkl"))

df = pd.concat([pd.read_pickle(str(p)) for p in pl], ignore_index=True)


df["depth"] = df.model.str.split("_", expand=True)[1].astype(int)
df["hidden"] = df.model.str.split("_", expand=True)[2].astype(int)
df["ds_"] = df['ds_self'].astype(str) +"-"+ df["ds_undir"].astype(str)

sns.relplot(data=df, x="hidden", y="val_acc", hue="ds_", style="drop_model", row="dataset", col="project", kind="line", errorbar=None, facet_kws={'sharey': "row", 'sharex': True})
#[df.dataset.eq("Computers")]
plt.xscale("log")
#plt.xscale('symlog', linthresh=0.00001)
#plt.xlim(0,0.1)
#plt.ylim(.87,.88)

# %%
pl = []

pl.append(Path("../results_comb/sage_p_Act0a1.pkl"))
pl.append(Path("../results_comb/sage_p_Act0a2.pkl"))
pl.append(Path("../results_comb/sage_p_Act0a3.pkl"))
pl.append(Path("../results_comb/sage_p_Ch0a1.pkl"))
pl.append(Path("../results_comb/sage_p_Ch0a2.pkl"))
pl.append(Path("../results_comb/sage_p_Ch0a3.pkl"))
pl.append(Path("../results_comb/sage_p_Cite0a1.pkl"))
pl.append(Path("../results_comb/sage_p_Cite0a2.pkl"))
pl.append(Path("../results_comb/sage_p_Cite0a3.pkl"))
pl.append(Path("../results_comb/sage_p_Com0a1.pkl"))
pl.append(Path("../results_comb/sage_p_Com0a2.pkl"))
pl.append(Path("../results_comb/sage_p_Com0a3.pkl"))
pl.append(Path("../results_comb/sage_p_Cora0a1.pkl"))
pl.append(Path("../results_comb/sage_p_Cora0a2.pkl"))
pl.append(Path("../results_comb/sage_p_Cora0a3.pkl"))
pl.append(Path("../results_comb/sage_p_Ms0a1.pkl"))
pl.append(Path("../results_comb/sage_p_Ms0a2.pkl"))
pl.append(Path("../results_comb/sage_p_Ms0a3.pkl"))
pl.append(Path("../results_comb/sage_p_PM0a1.pkl"))
pl.append(Path("../results_comb/sage_p_PM0a2.pkl"))
pl.append(Path("../results_comb/sage_p_PM0a3.pkl"))
pl.append(Path("../results_comb/sage_p_Pho0a1.pkl"))
pl.append(Path("../results_comb/sage_p_Pho0a2.pkl"))
pl.append(Path("../results_comb/sage_p_Pho0a3.pkl"))
pl.append(Path("../results_comb/sage_p_Re0a1.pkl"))
pl.append(Path("../results_comb/sage_p_Re0a2.pkl"))
pl.append(Path("../results_comb/sage_p_Re0a3.pkl"))
pl.append(Path("../results_comb/sage_p_Sq0a1.pkl"))
pl.append(Path("../results_comb/sage_p_Sq0a2.pkl"))
pl.append(Path("../results_comb/sage_p_Sq0a3.pkl"))
pl.append(Path("../results_comb/sage_p_Arx0a1.pkl"))
pl.append(Path("../results_comb/sage_p_Arx0a2.pkl"))
pl.append(Path("../results_comb/sage_p_Arx0a3.pkl"))

df = pd.concat([pd.read_pickle(str(p)) for p in pl], ignore_index=True)

#df[df.batch_size.eq("2x50")].batch_size = "1x100"

df["optim_type"] = df['base_optim'].astype(str) +"-"+ df["model_type"].astype(str)

#[df.dataset.eq("Computers")]
sns.relplot(data=df[df.dataset.eq("Arxiv")], x="drop_model", y="val_acc", hue="model", style="batch_size", row="dataset", col="optim_type", kind="line", errorbar=None, facet_kws={'sharey': "row", 'sharex': True})
#plt.xscale("log")
#plt.xscale('symlog', linthresh=0.00001)
#plt.xlim(0,0.1)
#plt.ylim(.93,.96)

# %%
pl = []

pl.append(Path("../results_comb/sage_ip_Act1.pkl"))
pl.append(Path("../results_comb/sage_ip_Ch1.pkl"))
pl.append(Path("../results_comb/sage_ip_Cite1.pkl"))
pl.append(Path("../results_comb/sage_ip_Com1.pkl"))
pl.append(Path("../results_comb/sage_ip_Cora1.pkl"))
pl.append(Path("../results_comb/sage_ip_Ms1.pkl"))
pl.append(Path("../results_comb/sage_ip_PM1.pkl"))
pl.append(Path("../results_comb/sage_ip_Pho1.pkl"))
pl.append(Path("../results_comb/sage_ip_Re1.pkl"))
pl.append(Path("../results_comb/sage_ip_Sq1.pkl"))
pl.append(Path("../results_comb/sage_ip_Arx1.pkl"))

df = pd.concat([pd.read_pickle(str(p)) for p in pl], ignore_index=True)

#df[df.batch_size.eq("2x50")].batch_size = "1x100"

#df["trim"] = df['tr_agg_in'].astype(str) +"-"+ df["tr_mid"].astype(str)

sns.relplot(data=df, x="weight_decay", y="val_acc", hue="drop_adj", style="drop_model", col="dataset", col_wrap=4, kind="line", errorbar=None, facet_kws={'sharey': False, 'sharex': True})
#plt.xscale("log")
plt.xscale('symlog', linthresh=0.00001)
plt.xlim(0,0.1)
#plt.ylim(.65,.73)

# %%
pl = []

pl.append(Path("../results_comb/sage_ip_Act0b.pkl"))
pl.append(Path("../results_comb/sage_ip_Ch0b.pkl"))
pl.append(Path("../results_comb/sage_ip_Cite0b.pkl"))
pl.append(Path("../results_comb/sage_ip_Com0b.pkl"))
pl.append(Path("../results_comb/sage_ip_Cora0b.pkl"))
pl.append(Path("../results_comb/sage_ip_Ms0b.pkl"))
pl.append(Path("../results_comb/sage_ip_PM0b.pkl"))
pl.append(Path("../results_comb/sage_ip_Pho0b.pkl"))
pl.append(Path("../results_comb/sage_ip_Re0b.pkl"))
pl.append(Path("../results_comb/sage_ip_Sq0b.pkl"))
pl.append(Path("../results_comb/sage_ip_Arx0b.pkl"))

df = pd.concat([pd.read_pickle(str(p)) for p in pl], ignore_index=True)


df["depth"] = df.model.str.split("_", expand=True)[1].astype(int)
df["hidden"] = df.model.str.split("_", expand=True)[2].astype(int)
df["ds_"] = df['ds_self'].astype(str) +"-"+ df["ds_undir"].astype(str)

sns.relplot(data=df, x="hidden", y="val_acc", hue="ds_", style="drop_model", row="dataset", col="project", kind="line", errorbar=None, facet_kws={'sharey': "row", 'sharex': True})
#[df.dataset.eq("Computers")]
plt.xscale("log")
#plt.xscale('symlog', linthresh=0.00001)
#plt.xlim(0,0.1)
#plt.ylim(.62,.67)

# %%
pl = []

pl.append(Path("../results_comb/sage_ip_Act0a1.pkl"))
pl.append(Path("../results_comb/sage_ip_Act0a2.pkl"))
pl.append(Path("../results_comb/sage_ip_Act0a3.pkl"))
pl.append(Path("../results_comb/sage_ip_Ch0a1.pkl"))
pl.append(Path("../results_comb/sage_ip_Ch0a2.pkl"))
pl.append(Path("../results_comb/sage_ip_Ch0a3.pkl"))
pl.append(Path("../results_comb/sage_ip_Cite0a1.pkl"))
pl.append(Path("../results_comb/sage_ip_Cite0a2.pkl"))
pl.append(Path("../results_comb/sage_ip_Cite0a3.pkl"))
pl.append(Path("../results_comb/sage_ip_Com0a1.pkl"))
pl.append(Path("../results_comb/sage_ip_Com0a2.pkl"))
pl.append(Path("../results_comb/sage_ip_Com0a3.pkl"))
pl.append(Path("../results_comb/sage_ip_Cora0a1.pkl"))
pl.append(Path("../results_comb/sage_ip_Cora0a2.pkl"))
pl.append(Path("../results_comb/sage_ip_Cora0a3.pkl"))
pl.append(Path("../results_comb/sage_ip_Ms0a1.pkl"))
pl.append(Path("../results_comb/sage_ip_Ms0a2.pkl"))
pl.append(Path("../results_comb/sage_ip_Ms0a3.pkl"))
pl.append(Path("../results_comb/sage_ip_PM0a1.pkl"))
pl.append(Path("../results_comb/sage_ip_PM0a2.pkl"))
pl.append(Path("../results_comb/sage_ip_PM0a3.pkl"))
pl.append(Path("../results_comb/sage_ip_Pho0a1.pkl"))
pl.append(Path("../results_comb/sage_ip_Pho0a2.pkl"))
pl.append(Path("../results_comb/sage_ip_Pho0a3.pkl"))
pl.append(Path("../results_comb/sage_ip_Re0a1.pkl"))
pl.append(Path("../results_comb/sage_ip_Re0a2.pkl"))
pl.append(Path("../results_comb/sage_ip_Re0a3.pkl"))
pl.append(Path("../results_comb/sage_ip_Sq0a1.pkl"))
pl.append(Path("../results_comb/sage_ip_Sq0a2.pkl"))
pl.append(Path("../results_comb/sage_ip_Sq0a3.pkl"))
pl.append(Path("../results_comb/sage_ip_Arx0a1.pkl"))
pl.append(Path("../results_comb/sage_ip_Arx0a2.pkl"))
pl.append(Path("../results_comb/sage_ip_Arx0a3.pkl"))

df = pd.concat([pd.read_pickle(str(p)) for p in pl], ignore_index=True)

#df[df.batch_size.eq("2x50")].batch_size = "1x100"

df["optim_type"] = df['base_optim'].astype(str) +"-"+ df["model_type"].astype(str)

#[df.dataset.eq("Computers")]
sns.relplot(data=df[df.dataset.eq("Arxiv")], x="drop_model", y="val_acc", hue="model", style="batch_size", row="dataset", col="optim_type", kind="line", errorbar=None, facet_kws={'sharey': "row", 'sharex': True})
#plt.xscale("log")
#plt.xscale('symlog', linthresh=0.00001)
#plt.xlim(0,0.1)
plt.ylim(.68,.72)

# %%
#inductive gcn 1
df["drop"] = df['drop_input'].astype(str) +"-"+ df["drop_adj"].astype(str)
df["drb"] = df['drop_model'].astype(str) +"-"+ df["base_optim"].astype(str)


sns.relplot(data=df, x="weight_decay", y="val_acc", hue="drop", style="drb", col="dataset", col_wrap= 4, kind="line", errorbar=None, facet_kws={'sharey': False, 'sharex': True})

plt.xscale('symlog', linthresh=0.00001)
plt.xlim(0,.1)
plt.ylim(.7,.73)

# %%
#inductive gcn 1
df["drop"] = df['drop_input'].astype(str) +"-"+ df["drop_adj"].astype(str)
df["drb"] = df['drop_model'].astype(str) +"-"+ df["base_optim"].astype(str)


sns.relplot(data=df, x="weight_decay", y="val_acc", hue="drop", style="drb", col="dataset", col_wrap= 4, kind="line", errorbar=None, facet_kws={'sharey': False, 'sharex': True})

plt.xscale('symlog', linthresh=0.00001)
plt.xlim(0,.1)

# %%
#gcn ind 0
df["wtf"] = df['model_type'].astype(str) +"-"+ df["base_optim"].astype(str)
df["ds_"] = df['ds_self'].astype(str) +"-"+ df["ds_undir"].astype(str)

df["d"] = df.model.str.split("_", expand=True)[1].astype(float)
df["hdim"] = df.model.str.split("_", expand=True)[2]


sns.relplot(data=df[df.ds_.eq("True-True")], x="d", y="val_acc", hue="hdim", style="wtf", row="dataset", col="drop_model", kind="line", errorbar=None, facet_kws={'sharey': "row", 'sharex': True})
plt.ylim(.65, .73)

# %%
#inductive gcn 0
df["wtf"] = df['model_type'].astype(str) +"-"+ df["base_optim"].astype(str)
df["ds_"] = df['ds_self'].astype(str) +"-"+ df["ds_undir"].astype(str)

#df2 = df[df.ds_undir.eq(True)]

sns.relplot(data=df, x="drop_model", y="val_acc", hue="model", style="wtf", row="dataset", col="ds_", kind="line", errorbar=None, facet_kws={'sharey': "row", 'sharex': True})

# %%
#gcn 1
df["drop"] = df['drop_input'].astype(str) +"-"+ df["drop_adj"].astype(str)
df["drb"] = df['drop_model'].astype(str) +"-"+ df["base_optim"].astype(str)


sns.relplot(data=df, x="weight_decay", y="val_acc", hue="drop", style="drb", col="dataset", col_wrap= 4, kind="line", errorbar=None, facet_kws={'sharey': False, 'sharex': True})

plt.xscale('symlog', linthresh=0.00001)
plt.xlim(0,.1)
plt.ylim(.71,.74)

# %%
#gcn 1
df["drop"] = df['drop_input'].astype(str) +"-"+ df["drop_adj"].astype(str)
df["drb"] = df['drop_model'].astype(str) +"-"+ df["base_optim"].astype(str)


sns.relplot(data=df, x="weight_decay", y="val_acc", hue="drop", style="drb", col="dataset", col_wrap= 4, kind="line", errorbar=None, facet_kws={'sharey': False, 'sharex': True})

plt.xscale('symlog', linthresh=0.00001)
plt.xlim(0,.1)

# %%
#gcn 0
df["wtf"] = df['model_type'].astype(str) +"-"+ df["base_optim"].astype(str)
df["ds_"] = df['ds_self'].astype(str) +"-"+ df["ds_undir"].astype(str)

df["d"] = df.model.str.split("_", expand=True)[1].astype(float)
df["hdim"] = df.model.str.split("_", expand=True)[2]


sns.relplot(data=df[df.ds_.eq("True-True")], x="d", y="val_acc", hue="hdim", style="wtf", row="dataset", col="drop_model", kind="line", errorbar=None, facet_kws={'sharey': "row", 'sharex': True})
#sns.relplot(data=df, x="drop_model", y="val_acc", hue="model", style="wtf", row="dataset", col="ds_", kind="line", errorbar=None, facet_kws={'sharey': "row", 'sharex': True})
plt.ylim(.7, .74)

# %%
#gcn 0
df["wtf"] = df['model_type'].astype(str) +"-"+ df["base_optim"].astype(str)
df["ds_"] = df['ds_self'].astype(str) +"-"+ df["ds_undir"].astype(str)

sns.relplot(data=df[df.dataset.eq("Roman-empire")], x="drop_model", y="val_acc", hue="model", style="wtf", row="dataset", col="ds_", kind="line", errorbar=None, facet_kws={'sharey': "row", 'sharex': True})
plt.ylim(.75,.84)

# %%
#gcn 0
df["wtf"] = df['model_type'].astype(str) +"-"+ df["base_optim"].astype(str)
df["ds_"] = df['ds_self'].astype(str) +"-"+ df["ds_undir"].astype(str)


sns.relplot(data=df, x="drop_model", y="val_acc", hue="model", style="wtf", row="dataset", col="ds_", kind="line", errorbar=None, facet_kws={'sharey': "row", 'sharex': True})

# %%
pl = []

pl.append(Path("../results_comb/smlpn_p_Cora1.pkl"))
pl.append(Path("../results_comb/smlpn_p_Cite1.pkl"))
pl.append(Path("../results_comb/smlpn_p_PM1.pkl"))
pl.append(Path("../results_comb/smlpn_p_Com1.pkl"))
pl.append(Path("../results_comb/smlpn_p_Pho1.pkl"))
pl.append(Path("../results_comb/smlpn_p_Ch1.pkl"))
pl.append(Path("../results_comb/smlpn_p_Sq1.pkl"))
pl.append(Path("../results_comb/smlpn_p_Act1.pkl"))
pl.append(Path("../results_comb/smlpn_p_Re1.pkl"))
pl.append(Path("../results_comb/smlpn_p_Ms1.pkl"))
pl.append(Path("../results_comb/smlpn_p_Arx1.pkl"))

df = pd.concat([pd.read_pickle(str(p)) for p in pl], ignore_index=True)



sns.relplot(data=df, x="weight_decay", y="val_acc", hue="drop_model", style="batch_size", col_wrap=4, col="dataset", kind="line", errorbar=None, facet_kws={'sharey': False, 'sharex': True})
#plt.ylim(.5, .6)

plt.xscale('symlog', linthresh=0.00001)
plt.xlim(0,.1)

# %%
pl = []

pl.append(Path("../results_comb/smlpn_p_hp0.pkl"))
pl.append(Path("../results_comb/smlpn_p_rem0.pkl"))
pl.append(Path("../results_comb/smlpn_p_rem0r.pkl"))
pl.append(Path("../results_comb/smlpn_p_rem0m.pkl"))

df = pd.concat([pd.read_pickle(str(p)) for p in pl], ignore_index=True)


df["d"] = df.model.str.split("_", expand=True)[1].astype(float)
df["hdim"] = df.model.str.split("_", expand=True)[2]
df["wtf"] = df['model_type'].astype(str) +"-"+ df["base_optim"].astype(str)



sns.relplot(data=df, x="d", y="val_acc", hue="hdim", style="batch_size", col="wtf", row="dataset", kind="line", errorbar=None, facet_kws={'sharey': "row", 'sharex': True})
#plt.ylim(.79, .801)

# %%
pl = []

pl.append(Path("../results_comb/smlpn_p_Cora0.pkl"))
pl.append(Path("../results_comb/smlpn_p_Cite0.pkl"))
pl.append(Path("../results_comb/smlpn_p_PM0.pkl"))
pl.append(Path("../results_comb/smlpn_p_Com0.pkl"))
pl.append(Path("../results_comb/smlpn_p_Pho0.pkl"))
pl.append(Path("../results_comb/smlpn_p_hp0.pkl"))
pl.append(Path("../results_comb/smlpn_p_Arx0sl.pkl"))
pl.append(Path("../results_comb/smlpn_p_Arx0sr.pkl"))
pl.append(Path("../results_comb/smlpn_p_Arx0dl.pkl"))
pl.append(Path("../results_comb/smlpn_p_Arx0dr.pkl"))

df = pd.concat([pd.read_pickle(str(p)) for p in pl], ignore_index=True)


df["d"] = df.model.str.split("_", expand=True)[1].astype(float)
df["hdim"] = df.model.str.split("_", expand=True)[2]
df["wtf"] = df['model_type'].astype(str) +"-"+ df["base_optim"].astype(str)



sns.relplot(data=df, x="d", y="val_acc", hue="hdim", style="batch_size", col="wtf", row="dataset", kind="line", errorbar=None, facet_kws={'sharey': "row", 'sharex': True})
#plt.ylim(.5, .6)

# %%
# mlp n2v 1
df["drop"] = df['drop_input'].astype(str) +"-"+ df["drop_model"].astype(str)


sns.relplot(data=df[df.dataset.eq("Arxiv")], x="weight_decay", y="val_acc", hue="drop", style="base_optim", row="dataset", col="model", kind="line", errorbar=None, facet_kws={'sharey':True, 'sharex': True})
plt.xscale('symlog', linthresh=0.00001)
plt.ylim(.63,.7)
plt.xlim(0,.1)

# %%
# mlp n2v 1
df["drop"] = df['drop_input'].astype(str) +"-"+ df["drop_model"].astype(str)


sns.relplot(data=df, x="weight_decay", y="val_acc", hue="drop", style="base_optim", col="dataset", col_wrap=4, kind="line", errorbar=None, facet_kws={'sharey':False, 'sharex': True})
plt.xscale('symlog', linthresh=0.00001)
plt.xlim(0,.1)

# %%
# mlpn 0 arx

df["d"] = df.model.str.split("_", expand=True)[1].astype(float)
df["hdim"] = df.model.str.split("_", expand=True)[2]

sns.relplot(data=df, x="d", y="val_acc", hue="hdim", style="drop_model", col="base_optim", row="model_type", kind="line", errorbar=None, facet_kws={'sharey': True, 'sharex': True})
plt.ylim(.64, .69)

# %%
# mlp n2v 0

df["d"] = df.model.str.split("_", expand=True)[1].astype(float)
df["hdim"] = df.model.str.split("_", expand=True)[2]
df["wtf"] = df['model_type'].astype(str) +"-"+ df["base_optim"].astype(str)



sns.relplot(data=df, x="d", y="val_acc", hue="hdim", style="drop_model", col="wtf", row="dataset", kind="line", errorbar=None, facet_kws={'sharey': "row", 'sharex': True})
#plt.ylim(.5, .6)

# %%
pl = []

pl.append(Path("../results_comb/smlp_p_Cora1.pkl"))
pl.append(Path("../results_comb/smlp_p_Cite1.pkl"))
pl.append(Path("../results_comb/smlp_p_PM1.pkl"))
pl.append(Path("../results_comb/smlp_p_Com1.pkl"))
pl.append(Path("../results_comb/smlp_p_Pho1.pkl"))
pl.append(Path("../results_comb/smlp_p_Ch1.pkl"))
pl.append(Path("../results_comb/smlp_p_Sq1.pkl"))
pl.append(Path("../results_comb/smlp_p_Act1.pkl"))
pl.append(Path("../results_comb/smlp_p_Re1.pkl"))
pl.append(Path("../results_comb/smlp_p_Arx1.pkl"))

df = pd.concat([pd.read_pickle(str(p)) for p in pl], ignore_index=True)



sns.relplot(data=df, x="weight_decay", y="val_acc", hue="drop_model", style="drop_input", col_wrap=4, col="dataset", kind="line", errorbar=None, facet_kws={'sharey': False, 'sharex': True})
#plt.ylim(.5, .6)

plt.xscale('symlog', linthresh=0.00001)
plt.xlim(0,.1)

# %%
pl = []

pl.append(Path("../results_comb/smlp_p_Cora0.pkl"))
pl.append(Path("../results_comb/smlp_p_Cite0.pkl"))
pl.append(Path("../results_comb/smlp_p_PM0.pkl"))
pl.append(Path("../results_comb/smlp_p_Com0.pkl"))
pl.append(Path("../results_comb/smlp_p_Pho0.pkl"))
pl.append(Path("../results_comb/smlp_p_hp0.pkl"))
pl.append(Path("../results_comb/smlp_p_rem0.pkl"))
pl.append(Path("../results_comb/smlp_p_Arx0s.pkl"))
pl.append(Path("../results_comb/smlp_p_Arx0d.pkl"))

df = pd.concat([pd.read_pickle(str(p)) for p in pl], ignore_index=True)


df["d"] = df.model.str.split("_", expand=True)[1].astype(float)
df["hdim"] = df.model.str.split("_", expand=True)[2]
df["wtf"] = df['model_type'].astype(str) +"-"+ df["base_optim"].astype(str)



sns.relplot(data=df, x="d", y="val_acc", hue="hdim", style="batch_size", col="wtf", row="dataset", kind="line", errorbar=None, facet_kws={'sharey': "row", 'sharex': True})
#plt.ylim(.5, .6)

# %%
# mlp 1 arxiv
dff = df[df.dataset.eq("Arxiv")]
sns.relplot(data=dff, x="weight_decay", y="val_acc", style="drop_model", hue="model", col="base_optim", row = "dataset", kind="line", errorbar=None, facet_kws={'sharey': True, 'sharex': True})

plt.xscale('symlog', linthresh=0.00001)
plt.xlim(0,.1)

# %%
# mlp 1
dff = df[df.batch_size.eq("full")]
sns.relplot(data=dff, x="weight_decay", y="val_acc", style="drop_model", hue="base_optim", col="dataset", col_wrap = 4, kind="line", errorbar=None, facet_kws={'sharey': False, 'sharex': True})

plt.xscale('symlog', linthresh=0.00001)
plt.xlim(0,.1)

# %%
# mlp pm 1
df["d"] = df.model.str.split("_", expand=True)[1].astype(float)
df["hdim"] = df.model.str.split("_", expand=True)[2]

dfPM = df[df.dataset.eq("PubMed")&df.model_type.eq("res")]


sns.relplot(data=dfPM, x="d", y="val_acc", hue="hdim", style="drop_model", row="dataset", col="base_optim", kind="line", errorbar=None, facet_kws={'sharey': "row", 'sharex': True})

# %%
# mlp not pm 1
dfa = df[df.dataset.ne("PubMed")&df.model_type.eq("lin")]

sns.relplot(data=dfa, x="d", y="val_acc", hue="hdim", style="drop_model", row="dataset", col="base_optim", kind="line", errorbar=None, facet_kws={'sharey': "row", 'sharex': True})

# %%
# mlp 0 Pro

df["d"] = df.model.str.split("_", expand=True)[1].astype(float)
df["hdim"] = df.model.str.split("_", expand=True)[2]

sns.relplot(data=df, x="d", y="val_acc", hue="hdim", style="drop_model", col="base_optim", row="model_type", kind="line", errorbar=None, facet_kws={'sharey': True, 'sharex': True})
plt.ylim(.75, .83)

# %%
# mlp 0 arx

df["d"] = df.model.str.split("_", expand=True)[1].astype(float)
df["hdim"] = df.model.str.split("_", expand=True)[2]

sns.relplot(data=df, x="d", y="val_acc", hue="hdim", style="drop_model", col="base_optim", row="model_type", kind="line", errorbar=None, facet_kws={'sharey': True, 'sharex': True})
plt.ylim(.5, .6)

# %%
sns.relplot(data=df, x="drop_model", y="val_acc", hue="model", style="ds_self", row="dataset", col="model_type", kind="line", errorbar=None, facet_kws={'sharey': "row", 'sharex': True})

# %%
#df["drop"] = df['drop_model'].astype(str) +"-"+ df["drop_input"].astype(str)
df["reg"] = df['weight_decay'].astype(str) +"-"+ df["drop_input"].astype(str)

sns.relplot(data=df, x="weight_decay", y="val_acc", hue="model", style="drop_input", row="dataset", col="model_type", kind="line", errorbar=None, facet_kws={'sharey': "row", 'sharex': True})

# %%
#df["drop"] = df['drop_model'].astype(str) +"-"+ df["drop_input"].astype(str)
df["reg"] = df['weight_decay'].astype(str) +"-"+ df["drop_input"].astype(str)

sns.relplot(data=df, x="weight_decay", y="val_acc", hue="model", style="drop_input", row="dataset", col="model_type", kind="line", errorbar=None, facet_kws={'sharey': "row", 'sharex': True})

# %% [markdown]
# ### fix hyp

# %%
pl = []

pl.append(Path("../results_comb/hyp_fix_Cora2.pkl"))

df = pd.concat([pd.read_pickle(str(p)) for p in pl], ignore_index=True)

sns.relplot(data=df, x="drop_model", y="val_acc", hue="drop_mix", style="weight_decay", col="drop_input", kind="line", errorbar=None, facet_kws={'sharey': True, 'sharex': True})
#plt.xscale("log")
#plt.xscale('symlog', linthresh=0.0001)
#plt.xlim(0,0.01)
#plt.ylim(.81,.84)

# %%
pl = []

pl.append(Path("../results_comb/hyp_fix_Cora1t.pkl"))
pl.append(Path("../results_comb/hyp_fix_Cora1f.pkl"))
pl.append(Path("../results_comb/hyp_fix_Cora1tm.pkl"))
pl.append(Path("../results_comb/hyp_fix_Cora1fm.pkl"))
pl.append(Path("../results_comb/hyp_fix_Cora1ds1.pkl"))
pl.append(Path("../results_comb/hyp_fix_Cora1ds2.pkl"))
pl.append(Path("../results_comb/hyp_fix_Cora1ds3.pkl"))

df = pd.concat([pd.read_pickle(str(p)) for p in pl], ignore_index=True)

#df[df.batch_size.eq("2x50")].batch_size = "1x100"

df["wd-drop"] = df['weight_decay'].astype(str) +"--"+ df["drop_model"].astype(str)
df["depth"] = df.model.str.split("_", expand=True)[1].astype(int)
df["hid-mix"] = df.model.str.split("_", expand=True)[2] + "--" + df.model.str.split("_", expand=True)[3]

df["hid-mix-trmid"] = df.model.str.split("_", expand=True)[2] + "--" + df.model.str.split("_", expand=True)[3] + "--"+ df.tr_mid.astype(str)
df["self-undir"] = df.ds_self.astype(str) + "--"+df.ds_undir.astype(str)


df["aggin-norm"] = df['tr_agg_in'].astype(str) +"--"+ df["norm_in"].astype(str)
df["mean-dr"] = df['aggr_mean'].astype(str) +"--"+ df["drop_model"].astype(str)

sns.relplot(data=df, x="weight_decay", y="val_acc", hue="hid-mix-trmid", style="mean-dr", col="aggin-norm", row="self-undir", kind="line", errorbar=None, facet_kws={'sharey': True, 'sharex': True})
#plt.xscale("log")
#plt.xscale('symlog', linthresh=0.0001)
#plt.xlim(0,0.01)
plt.ylim(.84,.85)

# %%
pl = []

pl.append(Path("../results_comb/hyp_fix_Cora01.pkl"))
pl.append(Path("../results_comb/hyp_fix_Cora02.pkl"))
pl.append(Path("../results_comb/hyp_fix_Cora03.pkl"))
pl.append(Path("../results_comb/hyp_fix_Cora0f.pkl"))
pl.append(Path("../results_comb/hyp_fix_Cora0fd.pkl"))

df = pd.concat([pd.read_pickle(str(p)) for p in pl], ignore_index=True)

#df[df.batch_size.eq("2x50")].batch_size = "1x100"

df["wd-drop"] = df['weight_decay'].astype(str) +"--"+ df["drop_model"].astype(str)
df["depth"] = df.model.str.split("_", expand=True)[1].astype(int)
df["hid-mix"] = df.model.str.split("_", expand=True)[2] + "--" + df.model.str.split("_", expand=True)[3]

df["type-lr"] = df['model_type'] +"--"+ df["base_optim"]

sns.relplot(data=df, x="depth", y="val_acc", hue="hid-mix", style="wd-drop", row="batch_size", col="type-lr", kind="line", errorbar=None, facet_kws={'sharey': True, 'sharex': True})
#plt.xscale("log")
#plt.xscale('symlog', linthresh=0.00001)
#plt.xlim(0,0.1)
plt.ylim(.8,.87)

# %%
pl = []

pl.append(Path("../results_comb/hyp_fix_Cite1t.pkl"))
pl.append(Path("../results_comb/hyp_fix_Cite1f.pkl"))
pl.append(Path("../results_comb/hyp_fix_Cite1tm.pkl"))
pl.append(Path("../results_comb/hyp_fix_Cite1fm.pkl"))

df = pd.concat([pd.read_pickle(str(p)) for p in pl], ignore_index=True)

#df[df.batch_size.eq("2x50")].batch_size = "1x100"

df["wd-drop"] = df['weight_decay'].astype(str) +"--"+ df["drop_model"].astype(str)
df["depth"] = df.model.str.split("_", expand=True)[1].astype(int)
df["hid-mix"] = df.model.str.split("_", expand=True)[2] + "--" + df.model.str.split("_", expand=True)[3]

df["aggin-norm"] = df['tr_agg_in'].astype(str) +"--"+ df["norm_in"].astype(str)
df["mean-dr"] = df['aggr_mean'].astype(str) +"--"+ df["drop_model"].astype(str)



sns.relplot(data=df, x="weight_decay", y="val_acc", hue="hid-mix", style="mean-dr", col="aggin-norm", row="tr_mid", kind="line", errorbar=None, facet_kws={'sharey': True, 'sharex': True})
#plt.xscale("log")
#plt.xscale('symlog', linthresh=0.0001)
#plt.xlim(0,0.01)
plt.ylim(.66,.69)

# %%
pl = []

pl.append(Path("../results_comb/hyp_fix_Cite01.pkl"))
pl.append(Path("../results_comb/hyp_fix_Cite02.pkl"))
pl.append(Path("../results_comb/hyp_fix_Cite03.pkl"))
pl.append(Path("../results_comb/hyp_fix_Cite0f.pkl"))
pl.append(Path("../results_comb/hyp_fix_Cite0fd.pkl"))

df = pd.concat([pd.read_pickle(str(p)) for p in pl], ignore_index=True)

#df[df.batch_size.eq("2x50")].batch_size = "1x100"

df["wd-drop"] = df['weight_decay'].astype(str) +"--"+ df["drop_model"].astype(str)
df["depth"] = df.model.str.split("_", expand=True)[1].astype(int)
df["hid-mix"] = df.model.str.split("_", expand=True)[2] + "--" + df.model.str.split("_", expand=True)[3]

df["type-lr"] = df['model_type'] +"--"+ df["base_optim"]

sns.relplot(data=df, x="depth", y="val_acc", hue="hid-mix", style="wd-drop", row="batch_size", col="type-lr", kind="line", errorbar=None, facet_kws={'sharey': True, 'sharex': True})
#plt.xscale("log")
#plt.xscale('symlog', linthresh=0.00001)
#plt.xlim(0,0.1)
plt.ylim(.6,.69)

# %%
pl = []

pl.append(Path("../results_comb/hyp_fix_PM1fffs.pkl"))
pl.append(Path("../results_comb/hyp_fix_PM1ffts.pkl"))
pl.append(Path("../results_comb/hyp_fix_PM1ftfs.pkl"))
pl.append(Path("../results_comb/hyp_fix_PM1ftts.pkl"))
pl.append(Path("../results_comb/hyp_fix_PM1tffs.pkl"))
pl.append(Path("../results_comb/hyp_fix_PM1tfts.pkl"))
pl.append(Path("../results_comb/hyp_fix_PM1ttfs.pkl"))
pl.append(Path("../results_comb/hyp_fix_PM1ttts.pkl"))

df = pd.concat([pd.read_pickle(str(p)) for p in pl], ignore_index=True)

df["wd-drop"] = df['weight_decay'].astype(str) +"--"+ df["drop_model"].astype(str)
df["depth"] = df.model.str.split("_", expand=True)[1].astype(int)
df["hid-mix-trmid"] = df.model.str.split("_", expand=True)[2] + "--" + df.model.str.split("_", expand=True)[3] + "--"+ df.tr_mid.astype(str)
df["hid-mix"] = df.model.str.split("_", expand=True)[2] + "--" + df.model.str.split("_", expand=True)[3] 

df["aggin-norm"] = df['tr_agg_in'].astype(str) +"--"+ df["norm_in"].astype(str)
df["mean-dr"] = df['aggr_mean'].astype(str) +"--"+ df["drop_model"].astype(str)

df["self-undir"] = df.ds_self.astype(str) + "--"+df.ds_undir.astype(str)

#df2 = df[df.ds_self.eq(False) & df.ds_undir.eq(True)]

#sns.relplot(data=df2, x="weight_decay", y="val_acc", hue="hid-mix", style="mean-dr", col="aggin-norm", row="tr_mid", kind="line", errorbar=None, facet_kws={'sharey': True, 'sharex': True})
sns.relplot(data=df, x="weight_decay", y="val_acc", hue="hid-mix-trmid", style="mean-dr", col="aggin-norm", row="self-undir", kind="line", errorbar=None, facet_kws={'sharey': True, 'sharex': True})
#plt.xscale("log")
#plt.xscale('symlog', linthresh=0.0001)
#plt.xlim(0,0.01)
plt.ylim(.78,.84)

# %%
pl = []

pl.append(Path("../results_comb/hyp_fix_PM01.pkl"))
pl.append(Path("../results_comb/hyp_fix_PM022.pkl"))
pl.append(Path("../results_comb/hyp_fix_PM027.pkl"))
pl.append(Path("../results_comb/hyp_fix_PM032.pkl"))
pl.append(Path("../results_comb/hyp_fix_PM037.pkl"))
pl.append(Path("../results_comb/hyp_fix_PM0f.pkl"))
pl.append(Path("../results_comb/hyp_fix_PM0fd.pkl"))

df = pd.concat([pd.read_pickle(str(p)) for p in pl], ignore_index=True)

#df[df.batch_size.eq("2x50")].batch_size = "1x100"

df["wd-drop"] = df['weight_decay'].astype(str) +"--"+ df["drop_model"].astype(str)
df["depth"] = df.model.str.split("_", expand=True)[1].astype(int)
df["hid-mix"] = df.model.str.split("_", expand=True)[2] + "--" + df.model.str.split("_", expand=True)[3]

df["type-lr"] = df['model_type'] +"--"+ df["base_optim"]

sns.relplot(data=df, x="depth", y="val_acc", hue="hid-mix", style="wd-drop", row="batch_size", col="type-lr", kind="line", errorbar=None, facet_kws={'sharey': True, 'sharex': True})
#plt.xscale("log")
#plt.xscale('symlog', linthresh=0.00001)
#plt.xlim(0,0.1)
plt.ylim(.81,.83)

# %%
pl = []

pl.append(Path("../results_comb/hyp_fix_Ch1ttt.pkl"))
pl.append(Path("../results_comb/hyp_fix_Ch1ttf.pkl"))
pl.append(Path("../results_comb/hyp_fix_Ch1tft.pkl"))
pl.append(Path("../results_comb/hyp_fix_Ch1ftt.pkl"))
pl.append(Path("../results_comb/hyp_fix_Ch1ftf.pkl"))
pl.append(Path("../results_comb/hyp_fix_Ch1fft.pkl"))

pl.append(Path("../results_comb/hyp_fix_Ch1tmtt.pkl"))
pl.append(Path("../results_comb/hyp_fix_Ch1tmtf.pkl"))
pl.append(Path("../results_comb/hyp_fix_Ch1tmft.pkl"))
pl.append(Path("../results_comb/hyp_fix_Ch1fmtt.pkl"))
pl.append(Path("../results_comb/hyp_fix_Ch1fmtf.pkl"))
pl.append(Path("../results_comb/hyp_fix_Ch1fmft.pkl"))


df = pd.concat([pd.read_pickle(str(p)) for p in pl], ignore_index=True)

#df[df.batch_size.eq("2x50")].batch_size = "1x100"

df["wd-drop"] = df['weight_decay'].astype(str) +"--"+ df["drop_model"].astype(str)
df["depth"] = df.model.str.split("_", expand=True)[1].astype(int)
#df["hid-mix-trmid"] = df.model.str.split("_", expand=True)[2] + "--" + df.model.str.split("_", expand=True)[3] + "--"+ df.tr_mid.astype(str)
df["hid-mix"] = df.model.str.split("_", expand=True)[2] + "--" + df.model.str.split("_", expand=True)[3] 

df["aggin-norm"] = df['tr_agg_in'].astype(str) +"--"+ df["norm_in"].astype(str)
df["mean-dr"] = df['aggr_mean'].astype(str) +"--"+ df["drop_model"].astype(str)

df["self-undir"] = df.ds_self.astype(str) + "--"+df.ds_undir.astype(str)

df2 = df[df.ds_self.eq(False) & df.ds_undir.eq(True)]

sns.relplot(data=df2, x="weight_decay", y="val_acc", hue="hid-mix", style="mean-dr", col="aggin-norm", row="tr_mid", kind="line", errorbar=None, facet_kws={'sharey': True, 'sharex': True})
#sns.relplot(data=df, x="weight_decay", y="val_acc", hue="hid-mix-trmid", style="mean-dr", col="aggin-norm", row="tr_mid", kind="line", errorbar=None, facet_kws={'sharey': True, 'sharex': True})
#plt.xscale("log")
#plt.xscale('symlog', linthresh=0.0001)
#plt.xlim(0,0.01)
plt.ylim(.75,.765)

# %%
pl = []

pl.append(Path("../results_comb/hyp_fix_Sq1ttt.pkl"))
pl.append(Path("../results_comb/hyp_fix_Sq1ttf.pkl"))
pl.append(Path("../results_comb/hyp_fix_Sq1tft.pkl"))
pl.append(Path("../results_comb/hyp_fix_Sq1ftt.pkl"))
pl.append(Path("../results_comb/hyp_fix_Sq1ftf.pkl"))
pl.append(Path("../results_comb/hyp_fix_Sq1fft.pkl"))

pl.append(Path("../results_comb/hyp_fix_Sq1ttt-.pkl"))
pl.append(Path("../results_comb/hyp_fix_Sq1ttf-.pkl"))
pl.append(Path("../results_comb/hyp_fix_Sq1tft-.pkl"))
pl.append(Path("../results_comb/hyp_fix_Sq1ftt-.pkl"))
pl.append(Path("../results_comb/hyp_fix_Sq1ftf-.pkl"))
pl.append(Path("../results_comb/hyp_fix_Sq1fft-.pkl"))

df = pd.concat([pd.read_pickle(str(p)) for p in pl], ignore_index=True)

#df[df.batch_size.eq("2x50")].batch_size = "1x100"

df["wd-drop"] = df['weight_decay'].astype(str) +"--"+ df["drop_model"].astype(str)
df["depth"] = df.model.str.split("_", expand=True)[1].astype(int)
df["hid-mix-trmid"] = df.model.str.split("_", expand=True)[2] + "--" + df.model.str.split("_", expand=True)[3] + "--"+ df.tr_mid.astype(str)
df["hid-mix"] = df.model.str.split("_", expand=True)[2] + "--" + df.model.str.split("_", expand=True)[3] 

df["aggin-norm"] = df['tr_agg_in'].astype(str) +"--"+ df["norm_in"].astype(str)
df["mean-dr"] = df['aggr_mean'].astype(str) +"--"+ df["drop_model"].astype(str)

df["self-undir"] = df.ds_self.astype(str) + "--"+df.ds_undir.astype(str)

df2 = df[df.ds_self.eq(False) & df.ds_undir.eq(True)]

sns.relplot(data=df2, x="weight_decay", y="val_acc", hue="hid-mix", style="mean-dr", col="aggin-norm", row="tr_mid", kind="line", errorbar=None, facet_kws={'sharey': True, 'sharex': True})
#sns.relplot(data=df, x="weight_decay", y="val_acc", hue="hid-mix-trmid", style="mean-dr", col="aggin-norm", row="self-undir", kind="line", errorbar=None, facet_kws={'sharey': True, 'sharex': True})
#plt.xscale("log")
#plt.xscale('symlog', linthresh=0.0001)
#plt.xlim(0,0.01)
plt.ylim(.6,.62)

# %%
pl = []

pl.append(Path("../results_comb/hyp_fix_Ch01.pkl"))
pl.append(Path("../results_comb/hyp_fix_Ch02.pkl"))
pl.append(Path("../results_comb/hyp_fix_Ch03.pkl"))
pl.append(Path("../results_comb/hyp_fix_Ch0f.pkl"))
pl.append(Path("../results_comb/hyp_fix_Ch0fd.pkl"))

df = pd.concat([pd.read_pickle(str(p)) for p in pl], ignore_index=True)

#df[df.batch_size.eq("2x50")].batch_size = "1x100"

df["wd-drop"] = df['weight_decay'].astype(str) +"--"+ df["drop_model"].astype(str)
df["depth"] = df.model.str.split("_", expand=True)[1].astype(int)
df["hid-mix"] = df.model.str.split("_", expand=True)[2] + "--" + df.model.str.split("_", expand=True)[3]

df["type-lr"] = df['model_type'] +"--"+ df["base_optim"]

sns.relplot(data=df, x="depth", y="val_acc", hue="hid-mix", style="wd-drop", row="batch_size", col="type-lr", kind="line", errorbar=None, facet_kws={'sharey': True, 'sharex': True})
#plt.xscale("log")
#plt.xscale('symlog', linthresh=0.00001)
#plt.xlim(0,0.1)
plt.ylim(.71,.72)

# %%
pl = []

pl.append(Path("../results_comb/hyp_fix_Sq01.pkl"))
pl.append(Path("../results_comb/hyp_fix_Sq02.pkl"))
pl.append(Path("../results_comb/hyp_fix_Sq021.pkl"))
pl.append(Path("../results_comb/hyp_fix_Sq022.pkl"))
pl.append(Path("../results_comb/hyp_fix_Sq023.pkl"))
pl.append(Path("../results_comb/hyp_fix_Sq024.pkl"))
pl.append(Path("../results_comb/hyp_fix_Sq03.pkl"))
pl.append(Path("../results_comb/hyp_fix_Sq031.pkl"))
pl.append(Path("../results_comb/hyp_fix_Sq032.pkl"))
pl.append(Path("../results_comb/hyp_fix_Sq033.pkl"))
pl.append(Path("../results_comb/hyp_fix_Sq034.pkl"))
pl.append(Path("../results_comb/hyp_fix_Sq0f.pkl"))

df = pd.concat([pd.read_pickle(str(p)) for p in pl], ignore_index=True)

#df[df.batch_size.eq("2x50")].batch_size = "1x100"

df["wd-drop"] = df['weight_decay'].astype(str) +"--"+ df["drop_model"].astype(str)
df["depth"] = df.model.str.split("_", expand=True)[1].astype(int)
df["hid-mix"] = df.model.str.split("_", expand=True)[2] + "--" + df.model.str.split("_", expand=True)[3]

df["type-lr"] = df['model_type'] +"--"+ df["base_optim"]

sns.relplot(data=df, x="depth", y="val_acc", hue="hid-mix", style="wd-drop", row="batch_size", col="type-lr", kind="line", errorbar=None, facet_kws={'sharey': True, 'sharex': True})
#plt.xscale("log")
#plt.xscale('symlog', linthresh=0.00001)
#plt.xlim(0,0.1)
plt.ylim(.60,.67)

# %%
pl = []

pl.append(Path("../results_comb/hyp_fix_Act1fft.pkl"))
pl.append(Path("../results_comb/hyp_fix_Act1ftf.pkl"))
pl.append(Path("../results_comb/hyp_fix_Act1ftt.pkl"))
pl.append(Path("../results_comb/hyp_fix_Act1tft.pkl"))
pl.append(Path("../results_comb/hyp_fix_Act1ttf.pkl"))
pl.append(Path("../results_comb/hyp_fix_Act1ttt.pkl"))

pl.append(Path("../results_comb/hyp_fix_Act1fftm.pkl"))
pl.append(Path("../results_comb/hyp_fix_Act1ftfm.pkl"))
pl.append(Path("../results_comb/hyp_fix_Act1fttm.pkl"))
pl.append(Path("../results_comb/hyp_fix_Act1tftm.pkl"))
pl.append(Path("../results_comb/hyp_fix_Act1ttfm.pkl"))
pl.append(Path("../results_comb/hyp_fix_Act1tttm.pkl"))

df = pd.concat([pd.read_pickle(str(p)) for p in pl], ignore_index=True)

#df[df.batch_size.eq("2x50")].batch_size = "1x100"

df["wd-drop"] = df['weight_decay'].astype(str) +"--"+ df["drop_model"].astype(str)
df["depth"] = df.model.str.split("_", expand=True)[1].astype(int)
df["hid-mix"] = df.model.str.split("_", expand=True)[2] + "--" + df.model.str.split("_", expand=True)[3]

df["aggin-norm"] = df['tr_agg_in'].astype(str) +"--"+ df["norm_in"].astype(str)
df["mean-dr"] = df['aggr_mean'].astype(str) +"--"+ df["drop_model"].astype(str)

df["self-undir"] = df.ds_self.astype(str) + "--"+df.ds_undir.astype(str)


sns.relplot(data=df[df.ds_self.eq(True) & df.ds_undir.eq(True)], x="weight_decay", y="val_acc", hue="hid-mix", style="mean-dr", col="aggin-norm", row="tr_mid", kind="line", errorbar=None, facet_kws={'sharey': True, 'sharex': True})
#plt.xscale("log")
#plt.xscale('symlog', linthresh=0.0001)
#plt.xlim(0,0.01)
plt.ylim(.386,.39)

# %%
pl = []

pl.append(Path("../results_comb/hyp_fix_Act1fft.pkl"))
pl.append(Path("../results_comb/hyp_fix_Act1ftf.pkl"))
pl.append(Path("../results_comb/hyp_fix_Act1ftt.pkl"))
pl.append(Path("../results_comb/hyp_fix_Act1tft.pkl"))
pl.append(Path("../results_comb/hyp_fix_Act1ttf.pkl"))
pl.append(Path("../results_comb/hyp_fix_Act1ttt.pkl"))

pl.append(Path("../results_comb/hyp_fix_Act1fftm.pkl"))
pl.append(Path("../results_comb/hyp_fix_Act1ftfm.pkl"))
pl.append(Path("../results_comb/hyp_fix_Act1fttm.pkl"))
pl.append(Path("../results_comb/hyp_fix_Act1tftm.pkl"))
pl.append(Path("../results_comb/hyp_fix_Act1ttfm.pkl"))
pl.append(Path("../results_comb/hyp_fix_Act1tttm.pkl"))

df = pd.concat([pd.read_pickle(str(p)) for p in pl], ignore_index=True)

#df[df.batch_size.eq("2x50")].batch_size = "1x100"

df["wd-drop"] = df['weight_decay'].astype(str) +"--"+ df["drop_model"].astype(str)
df["depth"] = df.model.str.split("_", expand=True)[1].astype(int)
df["hid-mix-trmid"] = df.model.str.split("_", expand=True)[2] + "--" + df.model.str.split("_", expand=True)[3] + "--"+ df.tr_mid.astype(str)

df["aggin-norm"] = df['tr_agg_in'].astype(str) +"--"+ df["norm_in"].astype(str)
df["mean-dr"] = df['aggr_mean'].astype(str) +"--"+ df["drop_model"].astype(str)

df["self-undir"] = df.ds_self.astype(str) + "--"+df.ds_undir.astype(str)


sns.relplot(data=df, x="weight_decay", y="val_acc", hue="hid-mix-trmid", style="mean-dr", col="aggin-norm", row="self-undir", kind="line", errorbar=None, facet_kws={'sharey': True, 'sharex': True})
#plt.xscale("log")
#plt.xscale('symlog', linthresh=0.0001)
#plt.xlim(0,0.01)
plt.ylim(.386,.39)

# %%
pl = []

pl.append(Path("../results_comb/hyp_fix_Act01.pkl"))
pl.append(Path("../results_comb/hyp_fix_Act02.pkl"))
pl.append(Path("../results_comb/hyp_fix_Act03.pkl"))
pl.append(Path("../results_comb/hyp_fix_Act0f.pkl"))

df = pd.concat([pd.read_pickle(str(p)) for p in pl], ignore_index=True)

#df[df.batch_size.eq("2x50")].batch_size = "1x100"

df["wd-drop"] = df['weight_decay'].astype(str) +"--"+ df["drop_model"].astype(str)
df["depth"] = df.model.str.split("_", expand=True)[1].astype(int)
df["hid-mix"] = df.model.str.split("_", expand=True)[2] + "--" + df.model.str.split("_", expand=True)[3]

df["type-lr"] = df['model_type'] +"--"+ df["base_optim"]

sns.relplot(data=df, x="depth", y="val_acc", hue="hid-mix", style="wd-drop", row="batch_size", col="type-lr", kind="line", errorbar=None, facet_kws={'sharey': True, 'sharex': True})
#plt.xscale("log")
#plt.xscale('symlog', linthresh=0.00001)
#plt.xlim(0,0.1)0
plt.ylim(.358,.37)

# %%
pl = []

pl.append(Path("../results_comb/hyp_ifix_Cora1t.pkl"))
pl.append(Path("../results_comb/hyp_ifix_Cora1f.pkl"))
pl.append(Path("../results_comb/hyp_ifix_Cora1tm.pkl"))
pl.append(Path("../results_comb/hyp_ifix_Cora1fm.pkl"))

df = pd.concat([pd.read_pickle(str(p)) for p in pl], ignore_index=True)

#df[df.batch_size.eq("2x50")].batch_size = "1x100"

df["wd-drop"] = df['weight_decay'].astype(str) +"--"+ df["drop_model"].astype(str)
df["depth"] = df.model.str.split("_", expand=True)[1].astype(int)
df["hid-mix"] = df.model.str.split("_", expand=True)[2] + "--" + df.model.str.split("_", expand=True)[3]

df["aggin-norm"] = df['tr_agg_in'].astype(str) +"--"+ df["norm_in"].astype(str)
df["mean-dr"] = df['aggr_mean'].astype(str) +"--"+ df["drop_model"].astype(str)



sns.relplot(data=df, x="weight_decay", y="val_acc", hue="hid-mix", style="mean-dr", col="aggin-norm", row="tr_mid", kind="line", errorbar=None, facet_kws={'sharey': True, 'sharex': True})
#plt.xscale("log")
#plt.xscale('symlog', linthresh=0.0001)
#plt.xlim(0,0.01)
plt.ylim(.77,.81)

# %%
pl = []

pl.append(Path("../results_comb/hyp_ifix_Cora01.pkl"))
pl.append(Path("../results_comb/hyp_ifix_Cora02.pkl"))
pl.append(Path("../results_comb/hyp_ifix_Cora03.pkl"))
pl.append(Path("../results_comb/hyp_ifix_Cora0f.pkl"))
pl.append(Path("../results_comb/hyp_ifix_Cora0fd.pkl"))

df = pd.concat([pd.read_pickle(str(p)) for p in pl], ignore_index=True)

#df[df.batch_size.eq("2x50")].batch_size = "1x100"

df["wd-drop"] = df['weight_decay'].astype(str) +"--"+ df["drop_model"].astype(str)
df["depth"] = df.model.str.split("_", expand=True)[1].astype(int)
df["hid-mix"] = df.model.str.split("_", expand=True)[2] + "--" + df.model.str.split("_", expand=True)[3]

df["type-lr"] = df['model_type'] +"--"+ df["base_optim"]

sns.relplot(data=df, x="depth", y="val_acc", hue="hid-mix", style="wd-drop", row="batch_size", col="type-lr", kind="line", errorbar=None, facet_kws={'sharey': True, 'sharex': True})
#plt.xscale("log")
#plt.xscale('symlog', linthresh=0.00001)
#plt.xlim(0,0.1)
plt.ylim(.76,.8)

# %%
pl = []

pl.append(Path("../results_comb/hyp_ifix_Cite1t.pkl"))
pl.append(Path("../results_comb/hyp_ifix_Cite1f.pkl"))
pl.append(Path("../results_comb/hyp_ifix_Cite1tm.pkl"))
pl.append(Path("../results_comb/hyp_ifix_Cite1fm.pkl"))

df = pd.concat([pd.read_pickle(str(p)) for p in pl], ignore_index=True)

#df[df.batch_size.eq("2x50")].batch_size = "1x100"

df["wd-drop"] = df['weight_decay'].astype(str) +"--"+ df["drop_model"].astype(str)
df["depth"] = df.model.str.split("_", expand=True)[1].astype(int)
df["hid-mix"] = df.model.str.split("_", expand=True)[2] + "--" + df.model.str.split("_", expand=True)[3]

df["aggin-norm"] = df['tr_agg_in'].astype(str) +"--"+ df["norm_in"].astype(str)
df["mean-dr"] = df['aggr_mean'].astype(str) +"--"+ df["drop_model"].astype(str)



sns.relplot(data=df, x="weight_decay", y="val_acc", hue="hid-mix", style="mean-dr", col="aggin-norm", row="tr_mid", kind="line", errorbar=None, facet_kws={'sharey': True, 'sharex': True})
#plt.xscale("log")
plt.xscale('symlog', linthresh=0.00001)
plt.xlim(0,0.01)
plt.ylim(.64,.67)

# %%
pl = []

pl.append(Path("../results_comb/hyp_ifix_Cite01.pkl"))
pl.append(Path("../results_comb/hyp_ifix_Cite02.pkl"))
pl.append(Path("../results_comb/hyp_ifix_Cite03.pkl"))
pl.append(Path("../results_comb/hyp_ifix_Cite0f.pkl"))
pl.append(Path("../results_comb/hyp_ifix_Cite0fd.pkl"))

df = pd.concat([pd.read_pickle(str(p)) for p in pl], ignore_index=True)

#df[df.batch_size.eq("2x50")].batch_size = "1x100"

df["wd-drop"] = df['weight_decay'].astype(str) +"--"+ df["drop_model"].astype(str)
df["depth"] = df.model.str.split("_", expand=True)[1].astype(int)
df["hid-mix"] = df.model.str.split("_", expand=True)[2] + "--" + df.model.str.split("_", expand=True)[3]

df["type-lr"] = df['model_type'] +"--"+ df["base_optim"]

sns.relplot(data=df, x="depth", y="val_acc", hue="hid-mix", style="wd-drop", row="batch_size", col="type-lr", kind="line", errorbar=None, facet_kws={'sharey': True, 'sharex': True})
#plt.xscale("log")
#plt.xscale('symlog', linthresh=0.00001)
#plt.xlim(0,0.1)
plt.ylim(.63,.65)

# %%
pl = []

pl.append(Path("../results_comb/hyp_ifix_Com1t.pkl"))
pl.append(Path("../results_comb/hyp_ifix_Com1f.pkl"))
pl.append(Path("../results_comb/hyp_ifix_Com1tm.pkl"))
pl.append(Path("../results_comb/hyp_ifix_Com1fm.pkl"))

df = pd.concat([pd.read_pickle(str(p)) for p in pl], ignore_index=True)

#df[df.batch_size.eq("2x50")].batch_size = "1x100"

df["wd-drop"] = df['weight_decay'].astype(str) +"--"+ df["drop_model"].astype(str)
df["depth"] = df.model.str.split("_", expand=True)[1].astype(int)
df["hid-mix"] = df.model.str.split("_", expand=True)[2] + "--" + df.model.str.split("_", expand=True)[3]

df["aggin-norm"] = df['tr_agg_in'].astype(str) +"--"+ df["norm_in"].astype(str)
df["mean-dr"] = df['aggr_mean'].astype(str) +"--"+ df["drop_model"].astype(str)


sns.relplot(data=df, x="weight_decay", y="val_acc", hue="hid-mix", style="mean-dr", row="tr_mid", col="aggin-norm", kind="line", errorbar=None, facet_kws={'sharey': True, 'sharex': True})
#plt.xscale("log")
#plt.xscale('symlog', linthresh=0.00001)
#plt.xlim(0,0.01)
plt.ylim(.85,.87)

# %%
pl = []

pl.append(Path("../results_comb/hyp_ifix_Com01.pkl"))
pl.append(Path("../results_comb/hyp_ifix_Com02.pkl"))
pl.append(Path("../results_comb/hyp_ifix_Com03.pkl"))
pl.append(Path("../results_comb/hyp_ifix_Com0f.pkl"))

df = pd.concat([pd.read_pickle(str(p)) for p in pl], ignore_index=True)

#df[df.batch_size.eq("2x50")].batch_size = "1x100"

df["wd-drop"] = df['weight_decay'].astype(str) +"--"+ df["drop_model"].astype(str)
df["depth"] = df.model.str.split("_", expand=True)[1].astype(int)
df["hid-mix"] = df.model.str.split("_", expand=True)[2] + "--" + df.model.str.split("_", expand=True)[3]

df["type-lr"] = df['model_type'] +"--"+ df["base_optim"]

sns.relplot(data=df, x="depth", y="val_acc", hue="hid-mix", style="wd-drop", row="batch_size", col="type-lr", kind="line", errorbar=None, facet_kws={'sharey': True, 'sharex': True})
#plt.xscale("log")
#plt.xscale('symlog', linthresh=0.00001)
#plt.xlim(0,0.1)
plt.ylim(.85,.87)

# %%
pl = []

pl.append(Path("../results_comb/hyp_ifix_Sq1ttt.pkl"))
pl.append(Path("../results_comb/hyp_ifix_Sq1ttf.pkl"))
pl.append(Path("../results_comb/hyp_ifix_Sq1tft.pkl"))
pl.append(Path("../results_comb/hyp_ifix_Sq1ftt.pkl"))
pl.append(Path("../results_comb/hyp_ifix_Sq1fft.pkl"))
pl.append(Path("../results_comb/hyp_ifix_Sq1ftf.pkl"))

df = pd.concat([pd.read_pickle(str(p)) for p in pl], ignore_index=True)

#df[df.batch_size.eq("2x50")].batch_size = "1x100"

df["wd-drop"] = df['weight_decay'].astype(str) +"--"+ df["drop_model"].astype(str)
df["depth"] = df.model.str.split("_", expand=True)[1].astype(int)
df["hid-mix-trmid"] = df.model.str.split("_", expand=True)[2] + "--" + df.model.str.split("_", expand=True)[3] + "--"+ df.tr_mid.astype(str)
#df["hid-mix"] = df.model.str.split("_", expand=True)[2] + "--" + df.model.str.split("_", expand=True)[3] 

df["aggin-norm"] = df['tr_agg_in'].astype(str) +"--"+ df["norm_in"].astype(str)
df["mean-dr"] = df['aggr_mean'].astype(str) +"--"+ df["drop_model"].astype(str)

df["self-undir"] = df.ds_self.astype(str) + "--"+df.ds_undir.astype(str)

#df2 = df[df.ds_self.eq(False) & df.ds_undir.eq(True)]

#sns.relplot(data=df2, x="weight_decay", y="val_acc", hue="hid-mix", style="mean-dr", col="aggin-norm", row="tr_mid", kind="line", errorbar=None, facet_kws={'sharey': True, 'sharex': True})
sns.relplot(data=df, x="weight_decay", y="val_acc", hue="hid-mix-trmid", style="mean-dr", col="aggin-norm", row="self-undir", kind="line", errorbar=None, facet_kws={'sharey': True, 'sharex': True})
#plt.xscale("log")
#plt.xscale('symlog', linthresh=0.0001)
#plt.xlim(0,0.01)
plt.ylim(.55,.59)

# %%
pl = []

pl.append(Path("../results_comb/hyp_ifix_Sq01.pkl"))
pl.append(Path("../results_comb/hyp_ifix_Sq02.pkl"))
pl.append(Path("../results_comb/hyp_ifix_Sq03.pkl"))
pl.append(Path("../results_comb/hyp_ifix_Sq0f.pkl"))
pl.append(Path("../results_comb/hyp_ifix_Sq0fd.pkl"))

df = pd.concat([pd.read_pickle(str(p)) for p in pl], ignore_index=True)

#df[df.batch_size.eq("2x50")].batch_size = "1x100"

df["wd-drop"] = df['weight_decay'].astype(str) +"--"+ df["drop_model"].astype(str)
df["depth"] = df.model.str.split("_", expand=True)[1].astype(int)
df["hid-mix"] = df.model.str.split("_", expand=True)[2] + "--" + df.model.str.split("_", expand=True)[3]

df["type-lr"] = df['model_type'] +"--"+ df["base_optim"]

df2 = df[df.model_type.eq("lin")]
sns.relplot(data=df2, x="depth", y="val_acc", hue="hid-mix", style="wd-drop", col="batch_size", row="type-lr", kind="line", errorbar=None, facet_kws={'sharey': True, 'sharex': True})
#plt.xscale("log")
#plt.xscale('symlog', linthresh=0.00001)
#plt.xlim(0,0.1)
plt.ylim(.54,.57)

# %% [markdown]
# ### hyp2 trans

# %%
pl = []

pl.append(Path("../results_comb/hyp2_p_Act10.pkl"))
pl.append(Path("../results_comb/hyp2_p_Act11.pkl"))
pl.append(Path("../results_comb/hyp2_p_Ch10.pkl"))
pl.append(Path("../results_comb/hyp2_p_Ch11.pkl"))
pl.append(Path("../results_comb/hyp2_p_Cite10.pkl"))
pl.append(Path("../results_comb/hyp2_p_Cite11.pkl"))
pl.append(Path("../results_comb/hyp2_p_Com10.pkl"))
pl.append(Path("../results_comb/hyp2_p_Cora10.pkl"))
pl.append(Path("../results_comb/hyp2_p_Cora11.pkl"))
pl.append(Path("../results_comb/hyp2_p_Ms10.pkl"))
pl.append(Path("../results_comb/hyp2_p_Ms11.pkl"))
pl.append(Path("../results_comb/hyp2_p_PM10.pkl"))
pl.append(Path("../results_comb/hyp2_p_PM11.pkl"))
pl.append(Path("../results_comb/hyp2_p_Pho10.pkl"))
pl.append(Path("../results_comb/hyp2_p_Pho11.pkl"))
pl.append(Path("../results_comb/hyp2_p_Re1.pkl"))
pl.append(Path("../results_comb/hyp2_p_Sq1.pkl"))
pl.append(Path("../results_comb/hyp2_p_Arx10.pkl"))
pl.append(Path("../results_comb/hyp2_p_Arx11.pkl"))

df = pd.concat([pd.read_pickle(str(p)) for p in pl], ignore_index=True)

#df[df.batch_size.eq("2x50")].batch_size = "1x100"

df["trim"] = df['tr_agg_in'].astype(str) +"-"+ df["tr_mid"].astype(str)

sns.relplot(data=df, x="weight_decay", y="val_acc", hue="trim", style="drop_model", row="dataset", col="drop_adj", kind="line", errorbar=None, facet_kws={'sharey': "row", 'sharex': True})
#plt.xscale("log")
plt.xscale('symlog', linthresh=0.00001)
plt.xlim(0,0.1)
#plt.ylim(.75,.95)

# %%
pl = []

pl.append(Path("../results_comb/hyp2_p_Act0bf.pkl"))
pl.append(Path("../results_comb/hyp2_p_Act0bt.pkl"))
pl.append(Path("../results_comb/hyp2_p_Act0bl.pkl"))
#pl.append(Path("../results_comb/hyp2_p_Act0bxl.pkl")) #bad res, screws colorscale
pl.append(Path("../results_comb/hyp2_p_Ch0bf.pkl"))
pl.append(Path("../results_comb/hyp2_p_Ch0bt.pkl"))
pl.append(Path("../results_comb/hyp2_p_Cite0bf.pkl"))
pl.append(Path("../results_comb/hyp2_p_Cite0bt.pkl"))
pl.append(Path("../results_comb/hyp2_p_Com0bt.pkl"))
pl.append(Path("../results_comb/hyp2_p_Com0bf.pkl"))
pl.append(Path("../results_comb/hyp2_p_Cora0bt.pkl"))
pl.append(Path("../results_comb/hyp2_p_Cora0bf.pkl"))
pl.append(Path("../results_comb/hyp2_p_Ms0btt.pkl"))
pl.append(Path("../results_comb/hyp2_p_Ms0btf.pkl"))
pl.append(Path("../results_comb/hyp2_p_Ms0bft.pkl"))
pl.append(Path("../results_comb/hyp2_p_Ms0bff.pkl"))
pl.append(Path("../results_comb/hyp2_p_PM0bf.pkl"))
pl.append(Path("../results_comb/hyp2_p_PM0bt.pkl"))
pl.append(Path("../results_comb/hyp2_p_Pho0bf.pkl"))
pl.append(Path("../results_comb/hyp2_p_Pho0bt.pkl"))
pl.append(Path("../results_comb/hyp2_p_Re0btt.pkl"))
pl.append(Path("../results_comb/hyp2_p_Re0btf.pkl"))
pl.append(Path("../results_comb/hyp2_p_Re0bft.pkl"))
pl.append(Path("../results_comb/hyp2_p_Re0bff.pkl"))
pl.append(Path("../results_comb/hyp2_p_Re0bl.pkl"))
pl.append(Path("../results_comb/hyp2_p_Sq0bf.pkl"))
pl.append(Path("../results_comb/hyp2_p_Sq0bt.pkl"))
pl.append(Path("../results_comb/hyp2_p_Sq0bl.pkl"))
pl.append(Path("../results_comb/hyp2_p_Arx0bf.pkl"))
pl.append(Path("../results_comb/hyp2_p_Arx0bt.pkl"))

df = pd.concat([pd.read_pickle(str(p)) for p in pl], ignore_index=True)

#df[df.batch_size.eq("2x50")].batch_size = "1x100"

df["depth"] = df.model.str.split("_", expand=True)[1].astype(int)
df["hidden"] = df.model.str.split("_", expand=True)[2].astype(int)
df["mix"] = df.model.str.split("_", expand=True)[3].astype(int)
df["hm"] = df.aggr_mean.astype(str) + "_" + df.drop_model.astype(str)
df["ds_"] = df['ds_self'].astype(str) +"-"+ df["ds_undir"].astype(str)

sns.relplot(data=df, x="mix", y="val_acc", hue="hidden", style="hm", row="dataset", col="ds_", kind="line", errorbar=None, facet_kws={'sharey': "row", 'sharex': True})
plt.xscale("log")
#plt.xscale('symlog', linthresh=0.00001)
#plt.xlim(0,0.1)
#plt.ylim(.85,.92)

# %%
pl = []

pl.append(Path("../results_comb/hyp2_p_Act0a1.pkl"))
pl.append(Path("../results_comb/hyp2_p_Act0a2.pkl"))
pl.append(Path("../results_comb/hyp2_p_Act0a3.pkl"))
pl.append(Path("../results_comb/hyp2_p_Ch0a1.pkl"))
pl.append(Path("../results_comb/hyp2_p_Ch0a2.pkl"))
pl.append(Path("../results_comb/hyp2_p_Ch0a3.pkl"))
pl.append(Path("../results_comb/hyp2_p_Cite0a1.pkl"))
pl.append(Path("../results_comb/hyp2_p_Cite0a2.pkl"))
pl.append(Path("../results_comb/hyp2_p_Cite0a3.pkl"))
pl.append(Path("../results_comb/hyp2_p_Com0a1.pkl"))
pl.append(Path("../results_comb/hyp2_p_Com0a2.pkl"))
pl.append(Path("../results_comb/hyp2_p_Com0a3.pkl"))
pl.append(Path("../results_comb/hyp2_p_Cora0a1.pkl"))
pl.append(Path("../results_comb/hyp2_p_Cora0a2.pkl"))
pl.append(Path("../results_comb/hyp2_p_Cora0a3.pkl"))
pl.append(Path("../results_comb/hyp2_p_Ms0a1.pkl"))
pl.append(Path("../results_comb/hyp2_p_Ms0a2.pkl"))
pl.append(Path("../results_comb/hyp2_p_Ms0a3.pkl"))
pl.append(Path("../results_comb/hyp2_p_PM0a1.pkl"))
pl.append(Path("../results_comb/hyp2_p_PM0a2.pkl"))
pl.append(Path("../results_comb/hyp2_p_PM0a3.pkl"))
pl.append(Path("../results_comb/hyp2_p_Pho0a1.pkl"))
pl.append(Path("../results_comb/hyp2_p_Pho0a2.pkl"))
pl.append(Path("../results_comb/hyp2_p_Pho0a3.pkl"))
pl.append(Path("../results_comb/hyp2_p_Re0a1.pkl"))
pl.append(Path("../results_comb/hyp2_p_Re0a2.pkl"))
pl.append(Path("../results_comb/hyp2_p_Re0a3.pkl"))
pl.append(Path("../results_comb/hyp2_p_Sq0a1.pkl"))
pl.append(Path("../results_comb/hyp2_p_Sq0a2.pkl"))
pl.append(Path("../results_comb/hyp2_p_Sq0a3.pkl"))
pl.append(Path("../results_comb/hyp2_p_Arx0a1.pkl"))
pl.append(Path("../results_comb/hyp2_p_Arx0a2.pkl"))
pl.append(Path("../results_comb/hyp2_p_Arx0a3.pkl"))

df = pd.concat([pd.read_pickle(str(p)) for p in pl], ignore_index=True)

#df[df.batch_size.eq("2x50")].batch_size = "1x100"

df["optim_type"] = df['base_optim'].astype(str) +"-"+ df["model_type"].astype(str)


sns.relplot(data=df, x="drop_model", y="val_acc", hue="model", style="batch_size", row="dataset", col="optim_type", kind="line", errorbar=None, facet_kws={'sharey': "row", 'sharex': True})
#plt.xscale("log")
#plt.xscale('symlog', linthresh=0.00001)
#plt.xlim(0,0.1)
plt.ylim(.66,.73)

# %% [markdown]
# ### hyp2 in

# %%
pl = []

pl.append(Path("../results_comb/hyp2_ip_Act1.pkl"))
pl.append(Path("../results_comb/hyp2_ip_Ch1.pkl"))
pl.append(Path("../results_comb/hyp2_ip_Cite1.pkl"))
pl.append(Path("../results_comb/hyp2_ip_Com1.pkl"))
pl.append(Path("../results_comb/hyp2_ip_Cora1.pkl"))
pl.append(Path("../results_comb/hyp2_ip_Ms1.pkl"))
pl.append(Path("../results_comb/hyp2_ip_PM1.pkl"))
pl.append(Path("../results_comb/hyp2_ip_Pho1.pkl"))
pl.append(Path("../results_comb/hyp2_ip_Re1.pkl"))
pl.append(Path("../results_comb/hyp2_ip_Sq1.pkl"))
pl.append(Path("../results_comb/hyp2_ip_Arx10.pkl"))
pl.append(Path("../results_comb/hyp2_ip_Arx11.pkl"))

df = pd.concat([pd.read_pickle(str(p)) for p in pl], ignore_index=True)

#df[df.batch_size.eq("2x50")].batch_size = "1x100"

df["trim"] = df['tr_agg_in'].astype(str) +"-"+ df["tr_mid"].astype(str)

sns.relplot(data=df, x="weight_decay", y="val_acc", hue="trim", style="drop_model", row="dataset", col="drop_adj", kind="line", errorbar=None, facet_kws={'sharey': "row", 'sharex': True})
#plt.xscale("log")
plt.xscale('symlog', linthresh=0.00001)
plt.xlim(0,0.1)
plt.ylim(.65,.73)

# %%
pl = []

pl.append(Path("../results_comb/hyp2_ip_Act0b.pkl"))
pl.append(Path("../results_comb/hyp2_ip_Ch0b.pkl"))
pl.append(Path("../results_comb/hyp2_ip_Ch0bl.pkl"))
pl.append(Path("../results_comb/hyp2_ip_Cite0bs.pkl"))
pl.append(Path("../results_comb/hyp2_ip_Cite0bl.pkl"))
pl.append(Path("../results_comb/hyp2_ip_Cite0bxl.pkl"))
pl.append(Path("../results_comb/hyp2_ip_Com0b.pkl"))
pl.append(Path("../results_comb/hyp2_ip_Com0bl.pkl"))
pl.append(Path("../results_comb/hyp2_ip_Cora0bt.pkl"))
pl.append(Path("../results_comb/hyp2_ip_Cora0bl.pkl"))
pl.append(Path("../results_comb/hyp2_ip_Cora0bxl.pkl"))
pl.append(Path("../results_comb/hyp2_ip_Ms0b.pkl"))
pl.append(Path("../results_comb/hyp2_ip_PM0bs.pkl"))
pl.append(Path("../results_comb/hyp2_ip_PM0bl.pkl"))
pl.append(Path("../results_comb/hyp2_ip_PM0bxl.pkl"))
pl.append(Path("../results_comb/hyp2_ip_Pho0bt.pkl"))
pl.append(Path("../results_comb/hyp2_ip_Pho0bl.pkl"))
pl.append(Path("../results_comb/hyp2_ip_Re0b.pkl"))
pl.append(Path("../results_comb/hyp2_ip_Sq0b.pkl"))
pl.append(Path("../results_comb/hyp2_ip_Arx0b.pkl"))

df = pd.concat([pd.read_pickle(str(p)) for p in pl], ignore_index=True)

#df[df.batch_size.eq("2x50")].batch_size = "1x100"

df["depth"] = df.model.str.split("_", expand=True)[1].astype(int)
df["hidden"] = df.model.str.split("_", expand=True)[2]
df["mix"] = df.model.str.split("_", expand=True)[3].astype(int)
df["hm"] = df.aggr_mean.astype(str) + "_" + df.drop_model.astype(str)
df["ds_"] = df['ds_self'].astype(str) +"-"+ df["ds_undir"].astype(str)

sns.relplot(data=df, x="mix", y="val_acc", hue="hidden", style="hm", row="dataset", col="ds_", kind="line", errorbar=None, facet_kws={'sharey': "row", 'sharex': True})
plt.xscale("log")
#plt.xscale('symlog', linthresh=0.00001)
#plt.xlim(0,0.1)
#plt.ylim(.46,.5)

# %%
pl = []

pl.append(Path("../results_comb/hyp2_ip_Act0a1.pkl"))
pl.append(Path("../results_comb/hyp2_ip_Act0a2.pkl"))
pl.append(Path("../results_comb/hyp2_ip_Act0a3.pkl"))
pl.append(Path("../results_comb/hyp2_ip_Ch0a1.pkl"))
pl.append(Path("../results_comb/hyp2_ip_Ch0a2.pkl"))
pl.append(Path("../results_comb/hyp2_ip_Ch0a3.pkl"))
pl.append(Path("../results_comb/hyp2_ip_Cite0a1.pkl"))
pl.append(Path("../results_comb/hyp2_ip_Cite0a2.pkl"))
pl.append(Path("../results_comb/hyp2_ip_Cite0a3.pkl"))
pl.append(Path("../results_comb/hyp2_ip_Com0a1.pkl"))
pl.append(Path("../results_comb/hyp2_ip_Com0a2.pkl"))
pl.append(Path("../results_comb/hyp2_ip_Com0a3.pkl"))
pl.append(Path("../results_comb/hyp2_ip_Cora0a1.pkl"))
pl.append(Path("../results_comb/hyp2_ip_Cora0a2.pkl"))
pl.append(Path("../results_comb/hyp2_ip_Cora0a3.pkl"))
pl.append(Path("../results_comb/hyp2_ip_Ms0a1.pkl"))
pl.append(Path("../results_comb/hyp2_ip_Ms0a2.pkl"))
pl.append(Path("../results_comb/hyp2_ip_Ms0a3.pkl"))
pl.append(Path("../results_comb/hyp2_ip_PM0a1.pkl"))
pl.append(Path("../results_comb/hyp2_ip_PM0a2.pkl"))
pl.append(Path("../results_comb/hyp2_ip_PM0a3.pkl"))
pl.append(Path("../results_comb/hyp2_ip_Pho0a1.pkl"))
pl.append(Path("../results_comb/hyp2_ip_Pho0a2.pkl"))
pl.append(Path("../results_comb/hyp2_ip_Pho0a3.pkl"))
pl.append(Path("../results_comb/hyp2_ip_Re0a1.pkl"))
pl.append(Path("../results_comb/hyp2_ip_Re0a2.pkl"))
pl.append(Path("../results_comb/hyp2_ip_Re0a3.pkl"))
pl.append(Path("../results_comb/hyp2_ip_Sq0a1.pkl"))
pl.append(Path("../results_comb/hyp2_ip_Sq0a2.pkl"))
pl.append(Path("../results_comb/hyp2_ip_Sq0a3.pkl"))
pl.append(Path("../results_comb/hyp2_ip_Arx0a1.pkl"))
pl.append(Path("../results_comb/hyp2_ip_Arx0a2.pkl"))
pl.append(Path("../results_comb/hyp2_ip_Arx0a3.pkl"))

df = pd.concat([pd.read_pickle(str(p)) for p in pl], ignore_index=True)

#df[df.batch_size.eq("2x50")].batch_size = "1x100"
df = df.replace("2x50", "1x100")

df["optim_type"] = df['base_optim'].astype(str) +"-"+ df["model_type"].astype(str)


sns.relplot(data=df, x="drop_model", y="val_acc", hue="model", style="batch_size", row="dataset", col="optim_type", kind="line", errorbar=None, facet_kws={'sharey': "row", 'sharex': True})
#sns.relplot(data=df[df.dataset.eq("Photo")], x="drop_model", y="val_acc", hue="model", style="batch_size", row="dataset", col="optim_type", kind="line", errorbar=None, facet_kws={'sharey': "row", 'sharex': True})
#plt.xscale("log")
#plt.xscale('symlog', linthresh=0.00001)
#plt.xlim(0,0.1)
#plt.ylim(.85,.95)

# %% [markdown]
# ### hyp ind

# %%
pl = []

pl.append(Path("../results_comb/hyp_ip_Cora1.pkl"))
pl.append(Path("../results_comb/hyp_ip_Cite1.pkl"))
pl.append(Path("../results_comb/hyp_ip_PM1.pkl"))
pl.append(Path("../results_comb/hyp_ip_Com1.pkl"))
pl.append(Path("../results_comb/hyp_ip_Pho1.pkl"))
pl.append(Path("../results_comb/hyp_ip_Mine1.pkl"))
pl.append(Path("../results_comb/hyp_ip_Rom1.pkl"))
pl.append(Path("../results_comb/hyp_ip_Ch1.pkl"))
pl.append(Path("../results_comb/hyp_ip_Sq1.pkl"))
pl.append(Path("../results_comb/hyp_ip_Act1.pkl"))
pl.append(Path("../results_comb/hyp_ip_Arx10.pkl"))
pl.append(Path("../results_comb/hyp_ip_Arx11.pkl"))


df = pd.concat([pd.read_pickle(str(p)) for p in pl], ignore_index=True)


#p1 ind bs
df["dropmi"] = df['drop_model'].astype(str) +"-"+ df["drop_adj"].astype(str)


sns.relplot(data=df, x="weight_decay", y="val_acc", hue="dropmi", style="aggr_mean", row="dataset", col="batch_size", kind="line", errorbar=None, facet_kws={'sharey': "row", 'sharex': True})
#plt.xscale("log")
plt.xscale('symlog', linthresh=0.00001)
plt.xlim(0,0.1)

# %%
pl = []

pl.append(Path("../results_comb/hyp_ip_Arx0_ff.pkl"))
pl.append(Path("../results_comb/hyp_ip_Arx0_ft.pkl"))
pl.append(Path("../results_comb/hyp_ip_Arx0_tf.pkl"))
pl.append(Path("../results_comb/hyp_ip_Arx0_tt.pkl"))

df = pd.concat([pd.read_pickle(str(p)) for p in pl], ignore_index=True)


df["depth"] = df.model.str.split("_", expand=True)[1].astype(int)
df["hidden"] = df.model.str.split("_", expand=True)[2].astype(int)
df["mix"] = df.model.str.split("_", expand=True)[3].astype(int)


df["mix_mid"] = df['tr_agg_mix'].astype(str) +"-"+ df["tr_mid"].astype(str)


sns.relplot(data=df, x="depth", y="val_acc", hue="mix", style="mix_mid", col="drop_model", kind="line", errorbar=None, facet_kws={'sharey': True, 'sharex': True})
#plt.xscale("log")
#plt.ylim(.6, .65)

# %%
pl = []

pl.append(Path("../results_comb/hyp_ip_Cora1.pkl"))
pl.append(Path("../results_comb/hyp_ip_Cite1.pkl"))
pl.append(Path("../results_comb/hyp_ip_PM1.pkl"))
pl.append(Path("../results_comb/hyp_ip_Com1.pkl"))
pl.append(Path("../results_comb/hyp_ip_Pho1.pkl"))
pl.append(Path("../results_comb/hyp_ip_Mine1.pkl"))
pl.append(Path("../results_comb/hyp_ip_Rom1.pkl"))
pl.append(Path("../results_comb/hyp_ip_Ch1.pkl"))
pl.append(Path("../results_comb/hyp_ip_Sq1.pkl"))
pl.append(Path("../results_comb/hyp_ip_Act1.pkl"))


df = pd.concat([pd.read_pickle(str(p)) for p in pl], ignore_index=True)



#p1 ind
df["dropmi"] = df['drop_model'].astype(str) +"-"+ df["drop_input"].astype(str)
df["dropam"] = df['drop_adj'].astype(str) +"-"+ df["drop_mix"].astype(str)


sns.relplot(data=df[df.dataset.eq("PubMed") ], x="weight_decay", y="val_acc", hue="dropmi", style="aggr_mean", col="batch_size", row="dropam", kind="line", errorbar=None, facet_kws={'sharey': True, 'sharex': True})
#plt.xscale("log")
plt.xscale('symlog', linthresh=0.00001)
plt.xlim(0,0.1)
#plt.ylim(.6, .65)

# %%
#p1 ind
df["dropmi"] = df['drop_model'].astype(str) +"-"+ df["drop_input"].astype(str)
df["dropam"] = df['drop_adj'].astype(str) +"-"+ df["drop_mix"].astype(str)


sns.relplot(data=df[df.dataset.eq("CiteSeer") & df.drop_adj.eq(0)], x="weight_decay", y="val_acc", hue="dropmi", style="aggr_mean", col="batch_size", row="dropam", kind="line", errorbar=None, facet_kws={'sharey': True, 'sharex': True})
#plt.xscale("log")
plt.xscale('symlog', linthresh=0.00001)
plt.xlim(0,0.1)
plt.ylim(.6, .65)

# %%
pl = []

pl.append(Path("../results_comb/hyp_ip_Cora1.pkl"))
pl.append(Path("../results_comb/hyp_ip_Cite1.pkl"))
pl.append(Path("../results_comb/hyp_ip_PM1.pkl"))
pl.append(Path("../results_comb/hyp_ip_Com1.pkl"))
pl.append(Path("../results_comb/hyp_ip_Pho1.pkl"))
pl.append(Path("../results_comb/hyp_ip_Mine1.pkl"))
pl.append(Path("../results_comb/hyp_ip_Rom1.pkl"))
pl.append(Path("../results_comb/hyp_ip_Ch1.pkl"))
pl.append(Path("../results_comb/hyp_ip_Sq1.pkl"))
pl.append(Path("../results_comb/hyp_ip_Act1.pkl"))


df = pd.concat([pd.read_pickle(str(p)) for p in pl], ignore_index=True)

#p1 ind
df["dropmi"] = df['drop_model'].astype(str) +"-"+ df["drop_input"].astype(str)
df["dropam"] = df['drop_adj'].astype(str) +"-"+ df["drop_mix"].astype(str)


sns.relplot(data=df, x="weight_decay", y="val_acc", hue="dropmi", style="aggr_mean", row="dataset", col="dropam", kind="line", errorbar=None, facet_kws={'sharey': "row", 'sharex': True})
#plt.xscale("log")
plt.xscale('symlog', linthresh=0.00001)
plt.xlim(0,0.1)

# %%
#p0 ind
#p0

df["aglr"] = df['aggr_mean'].astype(str) +"-"+ df["base_optim"].astype(str)
df["ds_"] = df['ds_self'].astype(str) +"-"+ df["ds_undir"].astype(str)

sns.relplot(data=df, x="drop_model", y="val_acc", hue="model", style="aglr", row="dataset", col = "ds_", kind="line", errorbar=None, facet_kws={'sharey': "row", 'sharex': True})
#plt.ylim(.7, .85)

# %% [markdown]
# ### hyp trans

# %%
pl = []
pl.append(Path("../results_comb/hyp_p_Arx11.pkl"))
pl.append(Path("../results_comb/hyp_p_Arx10.pkl"))
df = pd.concat([pd.read_pickle(str(p)) for p in pl], ignore_index=True)


df["drop"] = df['drop_model'].astype(str) +"-"+ df["drop_input"].astype(str)

df["agad"] = df['aggr_mean'].astype(str) +"-"+ df["drop_adj"].astype(str)

sns.relplot(data=df, x="weight_decay", y="val_acc", hue="drop", style="agad", col="dataset", col_wrap=4, kind="line", errorbar=None, facet_kws={'sharey': False, 'sharex': True})
#plt.xscale("log")
plt.xscale('symlog', linthresh=0.00001)
plt.xlim(0,0.1)

# %%
pl = []
pl.append(Path("../results_comb/hyp_p_Arx0_ff.pkl"))
pl.append(Path("../results_comb/hyp_p_Arx0_ft.pkl"))
pl.append(Path("../results_comb/hyp_p_Arx0_tf.pkl"))
pl.append(Path("../results_comb/hyp_p_Arx0_tt.pkl"))
df = pd.concat([pd.read_pickle(str(p)) for p in pl], ignore_index=True)


df["mix"] = df.model.str.split("_", expand=True)[3].astype(int)
df["hidden"] = df.model.str.split("_", expand=True)[2].astype(int)

sns.relplot(data=df, x="drop_model", y="val_acc", hue="model", style="tr_mid", col="tr_agg_mix", kind="line", errorbar=None, facet_kws={'sharey': True, 'sharex': True})
#plt.xscale("log")

# %%
df[df.model.eq("HCM_3_512_128")]

# %%
#p1
pl = []
pl.append(Path("../results_comb/hyp_test_Arx_batch.pkl"))
df = pd.concat([pd.read_pickle(str(p)) for p in pl], ignore_index=True)


sns.relplot(data=df, x="base_optim", y="val_acc", hue="batch_size", kind="line", errorbar=None, facet_kws={'sharey': False, 'sharex': True})
#plt.xscale("log")

# %%
#p1
pl = []
pl.append(Path("../results_comb/hyp_test_Arx_w1.pkl"))
pl.append(Path("../results_comb/hyp_test_Arx_w2.pkl"))
pl.append(Path("../results_comb/hyp_test_Arx_w3.pkl"))
df = pd.concat([pd.read_pickle(str(p)) for p in pl], ignore_index=True)


df["mix"] = df.model.str.split("_", expand=True)[3].astype(int)
df["hidden"] = df.model.str.split("_", expand=True)[2].astype(int)

sns.relplot(data=df, x="hidden", y="val_acc", hue="mix", kind="line", errorbar=None, facet_kws={'sharey': False, 'sharex': True})
#plt.xscale("log")

# %%
#p1
pl = []
pl.append(Path("../results_comb/hyp_p_Cora1.pkl"))
pl.append(Path("../results_comb/hyp_p_Cite1.pkl"))
pl.append(Path("../results_comb/hyp_p_PM1.pkl"))
pl.append(Path("../results_comb/hyp_p_Com1.pkl"))
pl.append(Path("../results_comb/hyp_p_Pho1.pkl"))
pl.append(Path("../results_comb/hyp_p_Mine1.pkl"))
pl.append(Path("../results_comb/hyp_p_Rom1.pkl"))
pl.append(Path("../results_comb/hyp_p_Ch1.pkl"))
pl.append(Path("../results_comb/hyp_p_Sq1.pkl"))
pl.append(Path("../results_comb/hyp_p_Act1.pkl"))
df = pd.concat([pd.read_pickle(str(p)) for p in pl], ignore_index=True)


df["drop"] = df['drop_model'].astype(str) +"-"+ df["drop_input"].astype(str)

df["agad"] = df['aggr_mean'].astype(str) +"-"+ df["drop_adj"].astype(str)

sns.relplot(data=df, x="weight_decay", y="val_acc", hue="drop", style="agad", col="dataset", col_wrap=4, kind="line", errorbar=None, facet_kws={'sharey': False, 'sharex': True})
#plt.xscale("log")
plt.xscale('symlog', linthresh=0.00001)
plt.xlim(0,0.1)

# %%
#p01

sns.relplot(data=df, x="drop_model", y="val_acc", hue="model", style="base_optim", col="dataset", col_wrap = 4, kind="line", errorbar=None, facet_kws={'sharey': False, 'sharex': True})

# %%
#p0
sns.relplot(data=df, x="drop_model", y="val_acc", hue="model", style="aggr_mean", col="dataset", col_wrap = 4, kind="line", errorbar=None, facet_kws={'sharey': False, 'sharex': True})

# %%
df["opt"] = df['base_optim'].astype(str) +"-"+ df["lr"].astype(str)

# %%
sns.relplot(data=df, x="weight_decay", y="val_acc", hue="model", style ="opt", col="dataset", row="drop_model", kind="line", errorbar=None)
plt.xscale('symlog', linthresh=0.0001)
plt.xlim(0,0.001)

# %%
sns.relplot(data=df, x="weight_decay", y="val_acc", hue="model", style ="drop_model", col="dataset",  kind="line", errorbar=None)
plt.ylim((0.6, 0.95))
plt.xscale('symlog', linthresh=0.00001)
plt.xlim(0,0.001)

# %%
sns.relplot(data=df, x="weight_decay", y="val_acc", style="drop_mix", hue ="drop_model", col="drop_input", row="dataset", kind="line", errorbar=None)
plt.ylim((0.75, 0.85))
plt.xscale('symlog', linthresh=0.00001)
plt.xlim(0,0.001)

# %%
df["opt"] = df['base_optim'].astype(str) +"-"+ df["lr"].astype(str)
sns.relplot(data=df[df.opt.eq("RMSprop-0.001")], x="weight_decay", y="val_acc", style="drop_model", hue ="batch_size", col="dataset", kind="line", errorbar=None)
plt.ylim((0.65, 0.90))
plt.xscale('symlog', linthresh=0.00001)
plt.xlim(0,0.001)

# %%
sns.relplot(data=df[df.batch_size.eq("20x1")], x="weight_decay", y="val_acc", style="lr", hue ="base_optim", row="drop_model", col="dataset", kind="line", errorbar=None)
plt.ylim((0.65, 0.90))
plt.xscale('symlog', linthresh=0.00001)
plt.xlim(0,0.001)

# %%
sns.relplot(data=df[df.batch_size.eq("10x1")], x="weight_decay", y="val_acc", style="lr", hue ="base_optim", row="drop_model", col="dataset", kind="line", errorbar=None)
plt.ylim((0.65, 0.90))
plt.xscale('symlog', linthresh=0.00001)
plt.xlim(0,0.001)

# %%
sns.relplot(data=df[df.batch_size.eq("1x1")], x="weight_decay", y="val_acc", style="lr", hue ="base_optim", row="drop_model", col="dataset", kind="line", errorbar=None)
plt.ylim((0.65, 0.90))
plt.xscale('symlog', linthresh=0.00001)
plt.xlim(0,0.001)

# %%
sns.relplot(data=df, x="weight_decay", y="trained_epochs", style="lr", hue ="base_optim", col="batch_size", row="dataset", kind="line", errorbar=None)
plt.xscale('symlog', linthresh=0.00001)
plt.xlim(0,0.001)
plt.ylim(0,100)

# %%
sns.relplot(data=df, x="weight_decay", y="val_acc", style="lr", hue ="base_optim", col="batch_size", row="dataset", kind="line", errorbar=None)
plt.ylim((0.6, 0.9))
plt.xscale('symlog', linthresh=0.00001)
plt.xlim(0,0.001)

# %%
sns.relplot(data=df, x="drop_model", y="val_acc", style="model", hue = "drop_mix", col="drop_input", row="dataset", kind="line", errorbar=None)
plt.ylim((0.72, 0.87))

# %%
sns.relplot(data=df, x="weight_decay", y="val_acc", hue="model", style = "drop_model", col="setup", row="dataset", kind="line", errorbar=None)
plt.xscale('symlog', linthresh=0.00001)
plt.xlim(0,0.01)
plt.ylim(0.72, 0.87)

# %%
sns.relplot(data=df, x="weight_decay", y="val_acc", hue="model", style = "batch_size", col="setup", row="dataset", kind="line", errorbar=None)
plt.xscale('symlog', linthresh=0.00001)
plt.xlim(0,0.001)

# %%
df["bs"] = df.batch_size.str.split("x", expand=True)[0].astype(int)
sns.relplot(data=df, x="bs", y="trained_epochs", style="model", col="setup", row="dataset", kind="line", errorbar=None)

# %%
df["bs"] = df.batch_size.str.split("x", expand=True)[0].astype(int)
sns.relplot(data=df, x="bs", y="val_acc", style="model", col="setup", row="dataset", kind="line", errorbar=None)

# %%
sns.relplot(data=df, x="weight_decay", y="val_acc", hue="dist_emb", style="model", col="batch_size", row="dataset", kind="line", errorbar=None)

# %%
sns.relplot(data=df, x="weight_decay", y="val_acc", hue="dist_emb", style="model", col="batch_size", row="dataset", kind="line", errorbar=None)

# %%
sns.relplot(data=df, x="drop_model", y="val_acc", hue="model", style="setup", col="dataset", kind="line", errorbar=None)

# %%
sns.relplot(data=df, x="drop_model", y="val_acc", hue="model", style="setup", col="dataset", kind="line", errorbar=None)

# %%
sns.relplot(data=df, x="drop_input", y="val_acc", hue="model", row="dataset")
